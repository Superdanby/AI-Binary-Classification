# %%
import sys

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# %%
all_df = pd.read_csv('./TraData.csv', low_memory=False)
res_df = pd.read_csv('./input.csv', low_memory=False)

# %%
print(all_df.columns.values)
# Out:
# ['adx' 'spaceType' 'spaceId' 'spaceCat' 'adType' 'ip' 'os' 'deviceType'
#  'publisherId' 'dclkVerticals' 'campaignId' 'advertiserId' 'click']

# %%
# preview the data
all_df.head()
# Out:
#                                             adx spaceType           spaceId  \
# 0  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  4d5aa536cd864b8d
# 1  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  df29ee4288fb474d
# 2  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  fabac3bca4a34996
# 3  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  946bc0ae7ddf40a3
# 4  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  4d5aa536cd864b8d
#
#   spaceCat adType                                            ip       os  \
# 0    IAB12  [3,9]  7Rud97q13Yk7EGzprFZy33wjYC3lKOkoc1jboz3ToXQ=  Android
# 1  IAB14_1  [3,9]  HrAoePTXzwTq5HChEWEPrcUeiXOotVgU0eYw3LrI7Pk=  Android
# 2    IAB12  [3,9]  MLTk/b+dXbPnYVL1Y6rA0Q8yL23r4CYoGLTuB9L00v0=  Android
# 3    IAB12  [3,9]  s/8/MB6H7Z7v6OqfbEEIbf7umyGRoT8cQGsCEapBOb0=  Windows
# 4    IAB12  [3,9]  vIEzEmgA7srRUPf3VWgcNEYEwasLE8wwU/EcDNNnn44=  Android
#
#   deviceType publisherId dclkVerticals  campaignId  advertiserId  click
# 0      Phone  5ad6008850           NaN        4612           266      0
# 1      Phone  ca10720d22           NaN        4619           215      0
# 2      Phone  adcfa8aac4           NaN        4597           215      0
# 3   Computer  de184afdf3           NaN        4608           173      0
# 4      Phone  5ad6008850           NaN        4612           266      0

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961457 entries, 0 to 961456
# Data columns (total 13 columns):
# adx              961457 non-null object
# spaceType        961457 non-null object
# spaceId          961457 non-null object
# spaceCat         961286 non-null object
# adType           961457 non-null object
# ip               961457 non-null object
# os               961457 non-null object
# deviceType       961457 non-null object
# publisherId      961457 non-null object
# dclkVerticals    1218 non-null object
# campaignId       961457 non-null int64
# advertiserId     961457 non-null int64
# click            961457 non-null int64
# dtypes: int64(3), object(10)
# memory usage: 95.4+ MB

# %%
all_df.describe()
# Out:
#           campaignId   advertiserId          click
# count  961457.000000  961457.000000  961457.000000
# mean     4609.638719     195.320444       0.000617
# std        25.889714      68.249918       0.024827
# min      4506.000000      16.000000       0.000000
# 25%      4603.000000     127.000000       0.000000
# 50%      4612.000000     215.000000       0.000000
# 75%      4627.000000     266.000000       0.000000
# max      4636.000000     273.000000       1.000000

# %%
all_df.describe(include=['O'])
# Out:
#                                                  adx spaceType  \
# count                                         961457    961457
# unique                                             2         2
# top     oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site
# freq                                          960239    958317
#
#                  spaceId spaceCat  adType  \
# count             961457   961286  961457
# unique               309       22       6
# top     4d5aa536cd864b8d    IAB12   [3,9]
# freq              207461   709981  958295
#
#                                                   ip       os deviceType  \
# count                                         961457   961457     961457
# unique                                        714922       14          3
# top     47DEQpj8HBSa+/TImW+5JCeuQeRkm5NMpJWZG3hSuFU=  Android      Phone
# freq                                            4266   415074     729615
#
#        publisherId dclkVerticals
# count       961457          1218
# unique          62           651
# top     5ad6008850            []
# freq        574610           162

# %%
for x in all_df.columns.values:
    print(all_df[x].value_counts())
    print("\n")
# Out:
# oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=    960239
# CuXcT8n6P0sIIAJUDjlunuV0ZnzP7p3Xf1jHLo2OlOE=      1218
# Name: adx, dtype: int64
#
#
# site    958317
# app       3140
# Name: spaceType, dtype: int64
#
#
# 4d5aa536cd864b8d            207461
# c60bd9fe77034acf            100203
# df29ee4288fb474d             68067
# fa604d518ae1467e             67354
# b5c7401fdb844f88             51410
# cb4ebda0667a420c             47348
# d0850c0f52434b05             40352
# 1a2687687697428b             39181
# fabac3bca4a34996             28905
# 31e5a397d5b446d6             16626
# 44846a9be8b9491e             12054
# 5bf9d630c1d145ad             11984
# fdf13d0e67b2490f             11645
# c60975775c6f4777             11341
# 1594dbbf247b46a1             10994
# f70c5595c6384911             10189
# 39bae4031f5749e5              9947
# 81565d0bbb714164              9332
# 468208fd4f584df9              8315
# 885942723ca24daa              7663
# 9ea6db12e4af4782              6426
# 946bc0ae7ddf40a3              5920
# f84a62779b074594              5447
# 534d9328b73f497e              5036
# b59f386c0ff246c5              5029
# 86947281878143cc              4911
# fb3abfe6db644c52              4878
# e0fbf3b24e694090              4524
# 7343e878f5224c06              4488
# b57e3ec4507e4bf1              4428
#                              ...
# fun01.net/3360280                1
# udn.com/250                      1
# ipeen.com.tw/3000600             1
# blogspot.tw/3360280              1
# dcard.tw/3000600                 1
# chinatimes.com/3000600           1
# pixnet.net/3940280               1
# others/3720280                   1
# stargogo.com/600                 1
# a7accaba28104914                 1
# bsxsw.com/3360280                1
# 1bf0eeda8dde463f                 1
# df410f8a29234fb5                 1
# others/4120280                   1
# others/3750280                   1
# others/3540280                   1
# pkget.com/280                    1
# ettoday.net/3000250              1
# technews.tw/600                  1
# 430048313aa748fe                 1
# others/3450280                   1
# fashionwaltz.com/3360280         1
# others/3920280                   1
# 81d5e453078546d8                 1
# 8a6096d978484f16                 1
# horofriend88.com/3360280         1
# nownews.com/600                  1
# blogspot.com/3360280             1
# 524d13f27492492c                 1
# pkget.com/4120280                1
# Name: spaceId, Length: 309, dtype: int64
#
#
# IAB12       709981
# IAB14_1     104502
# IAB9_30      77573
# IAB17        17858
# IAB1         17701
# IAB19        11485
# IAB8         11046
# IAB18         5732
# IAB3          1875
# IAB9           772
# IAB20          717
# IAB22          692
# IAB7           455
# IAB19_18       367
# IAB13          164
# IAB1_1         161
# IAB2           117
# IAB16           66
# IAB10           17
# IAB15            2
# IAB4             2
# IAB11            1
# Name: spaceCat, dtype: int64
#
#
# [3,9]            958295
# [4]                1790
# [1,2,5,7]           770
# [1,2,5,6,7]         448
# [1,2,5,7,8]         105
# [1,2,5,6,7,8]        49
# Name: adType, dtype: int64
#
#
# 47DEQpj8HBSa+/TImW+5JCeuQeRkm5NMpJWZG3hSuFU=    4266
# sbBK8U1MoK6JstNasQEvbHU1Pt6n10SF1G5nL9Fhbp8=     289
# fRQJESJejmoqiBJSJtIB0c/AW15j6xJ/vPiwmTaa8nU=     272
# 04M932pgr5m//DUQ3wAr9yYWb63TCSGmTggOO0yTSdo=     227
# kCM/BZz7oMrVGqKhzs4o/uVhP5S0Oy9XriQtkZYc4Qg=     176
# aHSbS1cpmW/MQoqVIhyKFvv1VQTW694qET8S6Xv1tz0=     126
# +gd8TcpOI9eADHav1ezambW039D5kKtnexcsEVc+kPo=     114
# ftWDR+NTjsTC6spD/S0pqR37aRT8r8QBffU6CQh3qWg=     112
# lciLjvmu02Vn+p4tnzQVYEOgVFy1zMiUFxo94dlRoc4=     111
# DVX7KB6kIANx7NARHnfb174J/DlGyqb0SrChT7ipWmg=     109
# /DwR/mbuWi1ZN+aPZzXFMj+U8b9aI4mDgWusYjzVQn0=     104
# FwCQ0l5mv0PiAgG5EjFr6aoW8HF3TQmhEIo4c+qDvWQ=     103
# SYkOI1g/Y7/s5e1Kn6CPtmjIGK3Izgl2swpD8YN9ABU=     100
# VKHyn0REXQdb11c2bq15/7gzsrNc8SdQup5goNLdBxE=      99
# AW1C+SLZIuJsiU+jcnphjnBohfaTDMLmhvqXI2v1iS8=      96
# CZ+X5loG3Vy4NTR7A3+4ontb7xBSWvnu2l00Dwag5O0=      95
# uG3eLgSPjxsSmP4XzKd5SjhSlIQ1GjwESSMR5icxu6w=      95
# mVNZZjW4uT5cVvQynssebP4fuNBG7uGWLXheRZAdFvo=      94
# 7udWSjNikIPwp052b8afxnX8UiK806jiLBsRNXmh3pY=      93
# peEUwI9j53rzzCAnMtbtifU9z0YRZ4izxq3E/MqW1oI=      93
# UlrEYDxp6E1ZV0OAiFgvZH3yDeLfocNe08Ynl4wyxkI=      92
# +3jaIoAJfqA7qDVI9DrpWzPdDGU11qvUBVhrwM3s3mY=      92
# PgrsJKeFhnoMdLNrLIgcAnvusFBeQ5goN3+oycvQCck=      92
# 4MtEEzbdg3UYSO6l+AZFpCyl4EtGhYkopLOndR3e7co=      92
# j8DNqGZ/J2pcfjFA5iAsqFsOkU2FIChzljXlTwsOWXE=      92
# pL3hJBssNrNcgguKi1uoUSUYzqzOzjOvMdqmeF6zf+o=      92
# 74pEF9nf3CyDscF1r0JhEHWH3eV0vOps7FzJ4yKY2sQ=      90
# +gTVqQvIqEyMHul8vDLfyMrd4xyIk2eioxy3sNq+Q8c=      89
# WaptWIdROed1sdScNTXR2uaq1l/1G/1PuWWO7w7jazk=      89
# NUh35nOcmWqOqmahXEdMUk+YeEtNgrHvS/VAiOu8mwU=      88
#                                                 ...
# R2lW1vcWyFDEdy3m3aSDbC6oOaUqkVdBAR7+oaQUIKA=       1
# kSoP1AhPgq2z7vPqdUEFx2SK+U0g6m0jTPLRd9e5+gg=       1
# u5MLVfqD5FXfAESgONZ51kJp5epYki9A+fMEVSplldY=       1
# 6Jd526ANpyoGTWN4qs32TH7yOsSRvLDZq2kZGgjl63I=       1
# +CpwDKh1TeUtEEUJGOujV0f86gj9k+Fshbbu7xtmcCk=       1
# Aw3A5W7PXcDrbF/UJ8/aCeKHVLA8IFYZXdm8txuZEl0=       1
# WL/XVXdmQojQNS5XNUKc6JJ+cDcfzcZI31oaYhxC7NQ=       1
# Hy3fPp2gfguasjLxvt0VdthfBjEyTEXNhwLtn3CbMtE=       1
# /hc3w9diODPub0FCNckWnHs2Po3eDiorFcxvim3qLxg=       1
# nDCTZG510fBYo7M6n3WJzKWFqoxO4kew90Ntz4eiIYg=       1
# d4LbLSqlUFY6NnK9lnrPC2pJfJI4mxd9B2zD9cMqW7w=       1
# 1NW2tij3GJEmsCjrRjK2UgOu9HhIe6SGEY+BN9TpGIY=       1
# fVu6vnXm8k8Y2ZWXv8tZDndAWisJba6ttWE/bUpsUyU=       1
# PbhiLjo+zLNA6ztwqZuXGNo4Ic/1gavlehpKc46nD5c=       1
# +ycf2r2UzWwfcJnpsG7nvF1NizVi05ynuZ4DoE7+lvo=       1
# uSB2rOoceI/zjV8D1eoEzRe1gStNXPB3SbnXjPTkRdc=       1
# kebwG/5aw6u42Isu4sbcCAMDSqhpDXfC6oleQ5iVYyc=       1
# X9I0QHbNrA3xf5gOg04izt0gweV95VatiyYe6sRlaW0=       1
# Kr69Wt7wGOLu+KmE4/R56EIV14+ZoM/y2cUafqdmiRw=       1
# 2IHeZGnHP/BInt9/lDg4Ob1zr88apdfExsh3aZ0kN5Q=       1
# PCfnCIqQuGRBRH0rMx10kkByF9K3N5Y5C1SBaIBB6tg=       1
# hBxcos++iQZJJ+Saofj/9kW2xsRHv2Je/6PdhAEOb0s=       1
# xg5VBhjZxkJp5JmsdFSBBUtKS95MCBko59CF3G0S97Q=       1
# ig2LdFhWjBYzo5kVerPTHXgL7m1wI+efWu0Pa1rknbY=       1
# dLP0ZsmUILMo9aoBI68J7zdjxtLWlcSfjJT8rSodJ88=       1
# 8IhDA0D+Q/Ef2KT2ellZnzg4RsdrckpHXxy7fCorQI4=       1
# ZOd2IEa92c3NVx1jB2caLk8JZni4sjAuXa4MChIwgdc=       1
# 66wayFDuKMywQzWA/vmARVxJGKMroPoeCcGKpQau1Rg=       1
# wRNanODF/Xq4GuNNPqLEOfSF6XfV3O2F38iRMR7J0Lw=       1
# eE320+xtRThNFweVWvRU6j0PVUgO7RXPSoiy4VebuqI=       1
# Name: ip, Length: 714922, dtype: int64
#
#
# Android          415074
# iOS              349206
# Windows          176464
# OS X              13174
# Unknown            4302
# Linux              1846
# android             636
# windows             431
# Windows Phone       173
# iphone              103
# ipad                 31
# mac                   9
# others                5
# BlackBerry            3
# Name: os, dtype: int64
#
#
# Phone       729615
# Computer    194017
# Tablet       37825
# Name: deviceType, dtype: int64
#
#
# 5ad6008850     574610
# a3036f8e67      77543
# ca10720d22      73514
# adcfa8aac4      38852
# 7260f81d98      34541
# b690e780f0      23140
# 558fb820ae      17852
# fadcc2c833      15593
# 9f8830f7bf      11264
# 7747c99aa4      10409
# 7e3fee842e      10093
# 1e0ce0bc6c       7853
# de184afdf3       6711
# 4ce500f989d      6426
# 6986953953       6291
# c5fcab9794       5716
# 1669db331b       4116
# 721f3799d6       4115
# 223727100b       4106
# 0e3a1a8bd8       4006
# 58f8225958       3140
# ba76c28c2c       2920
# 17ff555b8c       1790
# 21910dc609       1786
# 6b52d2a6e8       1649
# bf0e29cd55       1580
# 26b5e4c061       1422
# 1073a27ffd       1415
# b92d94c79d       1349
# 4a101d0c29       1306
#                 ...
# 9dd3332fdc        919
# 755dffed4e        617
# a92833a3ef        484
# 4113dd3c7b        330
# 042f5cf04b        165
# 483683f751        156
# e99b6a548b        152
# 46c7f4c651        141
# 78d13f130c        123
# 4996d019b0        122
# b1892a47b3        119
# 5b1287fe69         97
# 0d4fb169f9         96
# a1af7f300f         80
# 492b25a971         63
# 445347f8e0         52
# 26579599ab         35
# 2c2f1d69de         32
# edf6bafad6         17
# 80cad8d6af         10
# c1393c1ab9          9
# cced0b5053          7
# c77d2964e5          5
# 57f5a2fd70          4
# 3046                2
# 3720                2
# 3640                1
# a25606c9b2          1
# 46cec11619f         1
# 0b9b2e3c02          1
# Name: publisherId, Length: 62, dtype: int64
#
#
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                               162
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                        115
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                             60
# [{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                            59
# [{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":182,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                       20
# [{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                             18
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                             16
# [{""""""""""""""""id"""""""""""""""":301,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":0.75}]                                                                                                                                                                                                                                                                                                        14
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":317,""""""""""""""""weight"""""""""""""""":0.4148325},{""""""""""""""""id"""""""""""""""":284,""""""""""""""""weight"""""""""""""""":0.1754304},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.4097371}]                                                                                                               12
# [{""""""""""""""""id"""""""""""""""":231,""""""""""""""""weight"""""""""""""""":0.38738245},{""""""""""""""""id"""""""""""""""":926,""""""""""""""""weight"""""""""""""""":0.61261755}]                                                                                                                                                                                                                                                                                            9
# [{""""""""""""""""id"""""""""""""""":408,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                              9
# [{""""""""""""""""id"""""""""""""""":1379,""""""""""""""""weight"""""""""""""""":0.469151},{""""""""""""""""id"""""""""""""""":926,""""""""""""""""weight"""""""""""""""":0.530849}]                                                                                                                                                                                                                                                                                               8
# [{""""""""""""""""id"""""""""""""""":870,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                    6
# [{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                              6
# [{""""""""""""""""id"""""""""""""""":622,""""""""""""""""weight"""""""""""""""":0.32967845},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":182,""""""""""""""""weight"""""""""""""""":0.23015402},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.44016755}]                                                                                                             5
# [{""""""""""""""""id"""""""""""""""":211,""""""""""""""""weight"""""""""""""""":0.2741867},{""""""""""""""""id"""""""""""""""":1049,""""""""""""""""weight"""""""""""""""":0.22269844},{""""""""""""""""id"""""""""""""""":1410,""""""""""""""""weight"""""""""""""""":0.3137925},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":409,""""""""""""""""weight"""""""""""""""":0.18932238}]                 4
# [{""""""""""""""""id"""""""""""""""":1033,""""""""""""""""weight"""""""""""""""":0.28872415},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1261,""""""""""""""""weight"""""""""""""""":0.34691334},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.3643625}]                                                                                                           3
# [{""""""""""""""""id"""""""""""""""":146,""""""""""""""""weight"""""""""""""""":0.76357377},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.23642623}]                                                                                                                                                                                                                                                                                            3
# [{""""""""""""""""id"""""""""""""""":203,""""""""""""""""weight"""""""""""""""":0.43641862},{""""""""""""""""id"""""""""""""""":1260,""""""""""""""""weight"""""""""""""""":0.5635814}]                                                                                                                                                                                                                                                                                            3
# [{""""""""""""""""id"""""""""""""""":396,""""""""""""""""weight"""""""""""""""":0.33365816},{""""""""""""""""id"""""""""""""""":16,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":259,""""""""""""""""weight"""""""""""""""":0.27461603},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.18912822},{""""""""""""""""id"""""""""""""""":409,""""""""""""""""weight"""""""""""""""":0.20259759}]                   3
# [{""""""""""""""""id"""""""""""""""":420,""""""""""""""""weight"""""""""""""""":0.20161456},{""""""""""""""""id"""""""""""""""":1364,""""""""""""""""weight"""""""""""""""":0.18937801},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.1960302},{""""""""""""""""id"""""""""""""""":949,""""""""""""""""weight"""""""""""""""":0.41297722}]                 3
# [{""""""""""""""""id"""""""""""""""":244,""""""""""""""""weight"""""""""""""""":0.23089036},{""""""""""""""""id"""""""""""""""":245,""""""""""""""""weight"""""""""""""""":0.7691096},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                        3
# [{""""""""""""""""id"""""""""""""""":525,""""""""""""""""weight"""""""""""""""":0.18400854},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.3274604},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.48853105}]                                                                                                              3
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.41626152},{""""""""""""""""id"""""""""""""""":1174,""""""""""""""""weight"""""""""""""""":0.5837385}]                                                                                                                                                                                                                                                                                            3
# [{""""""""""""""""id"""""""""""""""":287,""""""""""""""""weight"""""""""""""""":0.27470013},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.72529984}]                                                                                                                                                                                                        2
# [{""""""""""""""""id"""""""""""""""":59,""""""""""""""""weight"""""""""""""""":0.19602315},{""""""""""""""""id"""""""""""""""":1135,""""""""""""""""weight"""""""""""""""":0.42667267},{""""""""""""""""id"""""""""""""""":237,""""""""""""""""weight"""""""""""""""":0.37730417}]                                                                                                                                                                                                 2
# [{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":429,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                         2
# [{""""""""""""""""id"""""""""""""""":211,""""""""""""""""weight"""""""""""""""":0.22451298},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":429,""""""""""""""""weight"""""""""""""""":0.775487}]                                                                                                                                                                                                         2
# [{""""""""""""""""id"""""""""""""""":982,""""""""""""""""weight"""""""""""""""":0.32470798},{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.675292}]                                                                                                                                                                                                                                                                                              2
# [{""""""""""""""""id"""""""""""""""":622,""""""""""""""""weight"""""""""""""""":0.32342705},{""""""""""""""""id"""""""""""""""":317,""""""""""""""""weight"""""""""""""""":0.30839115},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":926,""""""""""""""""weight"""""""""""""""":0.3681818}]                                                                                                             2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# [{""""""""""""""""id"""""""""""""""":179,""""""""""""""""weight"""""""""""""""":0.31423333},{""""""""""""""""id"""""""""""""""":1010,""""""""""""""""weight"""""""""""""""":0.42816016},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.2576065}]                                                                                                                                                                                                 1
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.41523308},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.5847669}]                                                                                                                                                                                                        1
# [{""""""""""""""""id"""""""""""""""":1133,""""""""""""""""weight"""""""""""""""":0.16802667},{""""""""""""""""id"""""""""""""""":1260,""""""""""""""""weight"""""""""""""""":0.21510297},{""""""""""""""""id"""""""""""""""":1193,""""""""""""""""weight"""""""""""""""":0.23033345},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.3865369}]                                                                                                    1
# [{""""""""""""""""id"""""""""""""""":420,""""""""""""""""weight"""""""""""""""":0.32319647},{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.2287159},{""""""""""""""""id"""""""""""""""":429,""""""""""""""""weight"""""""""""""""":0.20574073},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.24234688}]                                                                                                       1
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1174,""""""""""""""""weight"""""""""""""""":0.40791973}]                                                                                                                                                                                                                                                                                                  1
# [{""""""""""""""""id"""""""""""""""":57,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":5058,""""""""""""""""weight"""""""""""""""":0.5}]                                                                                                                                                                                                                                                                                                          1
# [{""""""""""""""""id"""""""""""""""":960,""""""""""""""""weight"""""""""""""""":0.47483343},{""""""""""""""""id"""""""""""""""":723,""""""""""""""""weight"""""""""""""""":0.16497597},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":802,""""""""""""""""weight"""""""""""""""":0.16931555}]                                                                                                             1
# [{""""""""""""""""id"""""""""""""""":211,""""""""""""""""weight"""""""""""""""":0.44631484},{""""""""""""""""id"""""""""""""""":885,""""""""""""""""weight"""""""""""""""":0.2783291},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":182,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.27535605}]                        1
# [{""""""""""""""""id"""""""""""""""":908,""""""""""""""""weight"""""""""""""""":0.30489224},{""""""""""""""""id"""""""""""""""":1551,""""""""""""""""weight"""""""""""""""":0.27699536},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.18389438},{""""""""""""""""id"""""""""""""""":1516,""""""""""""""""weight"""""""""""""""":0.23421802}]               1
# [{""""""""""""""""id"""""""""""""""":630,""""""""""""""""weight"""""""""""""""":0.36893633},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":429,""""""""""""""""weight"""""""""""""""":0.324133},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.30693066}]                                                                                                              1
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.7090058},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.29099423}]                                                                                                                                                                                                        1
# [{""""""""""""""""id"""""""""""""""":1135,""""""""""""""""weight"""""""""""""""":0.25234842},{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.32785392},{""""""""""""""""id"""""""""""""""":1174,""""""""""""""""weight"""""""""""""""":0.22381698},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.1959807}]                                                                                                     1
# [{""""""""""""""""id"""""""""""""""":5032,""""""""""""""""weight"""""""""""""""":0.22469532},{""""""""""""""""id"""""""""""""""":179,""""""""""""""""weight"""""""""""""""":0.116169184},{""""""""""""""""id"""""""""""""""":1078,""""""""""""""""weight"""""""""""""""":0.12542562},{""""""""""""""""id"""""""""""""""":5059,""""""""""""""""weight"""""""""""""""":0.27530468},{""""""""""""""""id"""""""""""""""":1010,""""""""""""""""weight"""""""""""""""":0.25840518}]      1
# [{""""""""""""""""id"""""""""""""""":33,""""""""""""""""weight"""""""""""""""":0.20877622},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1260,""""""""""""""""weight"""""""""""""""":0.19788744},{""""""""""""""""id"""""""""""""""":1095,""""""""""""""""weight"""""""""""""""":0.2118678}]                                                                                                             1
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.57773376},{""""""""""""""""id"""""""""""""""":1174,""""""""""""""""weight"""""""""""""""":0.42226627}]                                                                                                                                                                                                                                                                                           1
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":926,""""""""""""""""weight"""""""""""""""":0.28816307},{""""""""""""""""id"""""""""""""""":372,""""""""""""""""weight"""""""""""""""":0.357126}]                                                                                                                                                                                                          1
# [{""""""""""""""""id"""""""""""""""":420,""""""""""""""""weight"""""""""""""""":0.21730684},{""""""""""""""""id"""""""""""""""":93,""""""""""""""""weight"""""""""""""""":0.21524368},{""""""""""""""""id"""""""""""""""":1174,""""""""""""""""weight"""""""""""""""":0.31231946},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.25513002}]                                                                                                      1
# [{""""""""""""""""id"""""""""""""""":105,""""""""""""""""weight"""""""""""""""":0.29983255},{""""""""""""""""id"""""""""""""""":622,""""""""""""""""weight"""""""""""""""":0.33613342},{""""""""""""""""id"""""""""""""""":1142,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":108,""""""""""""""""weight"""""""""""""""":0.36403403}]                                                                                                            1
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1193,""""""""""""""""weight"""""""""""""""":0.28928828},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.7107117}]                                                                                                                                                                                                        1
# [{""""""""""""""""id"""""""""""""""":138,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                              1
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.54248214},{""""""""""""""""id"""""""""""""""":449,""""""""""""""""weight"""""""""""""""":0.18255015},{""""""""""""""""id"""""""""""""""":1174,""""""""""""""""weight"""""""""""""""":0.27496773}]                                                                                                                                                                                                1
# [{""""""""""""""""id"""""""""""""""":449,""""""""""""""""weight"""""""""""""""":0.6862465},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.3137535}]                                                                                                                                                                                                                                                                                              1
# [{""""""""""""""""id"""""""""""""""":138,""""""""""""""""weight"""""""""""""""":0.63098913},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.36901087}]                                                                                                                                                                                                       1
# [{""""""""""""""""id"""""""""""""""":907,""""""""""""""""weight"""""""""""""""":0.4636138},{""""""""""""""""id"""""""""""""""":122,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1526,""""""""""""""""weight"""""""""""""""":0.31040227}]                                                                                                                                                                                                        1
# [{""""""""""""""""id"""""""""""""""":662,""""""""""""""""weight"""""""""""""""":0.33808023},{""""""""""""""""id"""""""""""""""":203,""""""""""""""""weight"""""""""""""""":0.44806004},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.21385972}]                                                                                                                                                                                                 1
# [{""""""""""""""""id"""""""""""""""":1193,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                             1
# [{""""""""""""""""id"""""""""""""""":211,""""""""""""""""weight"""""""""""""""":0.32398129},{""""""""""""""""id"""""""""""""""":1310,""""""""""""""""weight"""""""""""""""":0.2573086},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1095,""""""""""""""""weight"""""""""""""""":0.4187101}]                                                                                                            1
# [{""""""""""""""""id"""""""""""""""":244,""""""""""""""""weight"""""""""""""""":0.25613725},{""""""""""""""""id"""""""""""""""":245,""""""""""""""""weight"""""""""""""""":0.39428946},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":93,""""""""""""""""weight"""""""""""""""":0.34957325}]                                                                                                             1
# [{""""""""""""""""id"""""""""""""""":236,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                              1
# [{""""""""""""""""id"""""""""""""""":365,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":1225,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":237,""""""""""""""""weight"""""""""""""""":0.32076004},{""""""""""""""""id"""""""""""""""":73,""""""""""""""""weight"""""""""""""""":0.3364217}]                                                                                                                    1
# Name: dclkVerticals, Length: 651, dtype: int64
#
#
# 4612    199557
# 4636    189655
# 4610    129622
# 4597     67173
# 4596     59460
# 4608     48434
# 4506     26825
# 4626     26588
# 4635     25052
# 4619     23958
# 4603     19668
# 4574     19234
# 4607     15388
# 4632     14499
# 4627     12685
# 4571     12575
# 4575     11382
# 4558      9730
# 4625      8814
# 4518      7804
# 4591      6011
# 4602      4269
# 4630      3870
# 4620      3670
# 4631      3307
# 4600      1450
# 4609      1329
# 4613      1131
# 4601      1116
# 4540      1063
# 4634      1048
# 4629       857
# 4633       742
# 4611       600
# 4628       566
# 4599       461
# 4588       431
# 4589       374
# 4604       309
# 4586       175
# 4587       166
# 4578       158
# 4623       152
# 4577        68
# 4621        17
# 4590         4
# 4614         4
# 4521         4
# 4576         2
# Name: campaignId, dtype: int64
# 94     214707
# 266    199557
# 173    179985
# 215    151809
# 271     56687
# 260     34629
# 127     19977
# 96      19236
# 272     15388
# 273     14499
# 237     12575
# 268     11382
# 265      9730
# 246      7296
# 250      6011
# 240      3687
# 269      1790
# 251      1135
# 267      1063
# 41        158
# 64        152
# 16          4
# Name: advertiserId, dtype: int64
#
#
# 0    960864
# 1       593
# Name: click, dtype: int64

# %%
adx = all_df.loc[:,('adx', 'click')]
adx['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
adx.groupby(['adx'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False)
# Out:
#                                             adx     click   count
# 0  CuXcT8n6P0sIIAJUDjlunuV0ZnzP7p3Xf1jHLo2OlOE=  0.000821    1218
# 1  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=  0.000617  960239

# %%
spt = all_df.loc[:,('spaceType', 'click')]
spt['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
spt.groupby(['spaceType'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False)
# Out:
#   spaceType     click   count
# 1      site  0.000619  958317
# 0       app  0.000000    3140

# %%
spd = all_df.loc[:,('spaceId', 'click')]
spd['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
spd.groupby(['spaceId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#               spaceId     click  count
# 105  7f068f54a11e4d56  0.120120    666
# 54   44b9221f3c5742d3  0.056604    742
# 229  fbadbe0b84574e6c  0.047619     21
# 119  8e2e462a46df4439  0.039122   1048
# 129  a0faeba51aec4944  0.037007   1216
# 110  835efb3468c24b8d  0.036364    330
# 205  e53805fd0b0f45d7  0.026087    230
# 191  d9055bc9592444e0  0.013475   2449
# 1    00b07139e7c2469f  0.012500     80
# 85   655005bab3a9414d  0.011494     87

# %%
sct = all_df.loc[:,('spaceCat', 'click')]
sct['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
sct.groupby(['spaceCat'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#     spaceCat     click   count
# 11  IAB19_18  0.032698     367
# 13      IAB2  0.008547     117
# 4      IAB13  0.006098     164
# 0       IAB1  0.005423   17701
# 5    IAB14_1  0.001646  104502
# 19      IAB8  0.001630   11046
# 15     IAB22  0.001445     692
# 20      IAB9  0.001295     772
# 9      IAB18  0.001221    5732
# 8      IAB17  0.000616   17858

# %%
adt = all_df.loc[:,('adType', 'click')]
adt['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
adt.groupby(['adType'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#           adType     click   count
# 5            [4]  0.046369    1790
# 3      [1,2,5,7]  0.001299     770
# 4          [3,9]  0.000531  958295
# 0  [1,2,5,6,7,8]  0.000000      49
# 1    [1,2,5,6,7]  0.000000     448
# 2    [1,2,5,7,8]  0.000000     105

# %%
ip = all_df.loc[:,('ip', 'click')]
ip['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
ip.groupby(['ip'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#                                                   ip  click  count
# 329527  RQEikp3eipwmVfhBjwR/y8m01J0p+fF9emMe5RTfpHk=    1.0      1
# 185973  EbO84/dGxPzxlsuF3+hPNgD8fnedwD8Ec+xBgV9YpAg=    1.0      1
# 407741  YTKRw6rz7VigqF+GQwUOBljyNE7ceNJYS6PSp9a0KRg=    1.0      1
# 31205   0mCHfOi7qOiprjoJAUJ+KC+7tXKOp2FwHlAhhqCDLZE=    1.0      1
# 442421  bXhKxDjPEabRXQUAUsONNJ1jXPXfxWkYDnukForHGxU=    1.0      1
# 10156   +uAuX0tIXxhHu1d/7LFR8+oQU3PZ/xwJc64SY2lgJJ4=    1.0      1
# 575581  nVD+fv9iOmVE6sXQtaNdVa9OfU/gEKobWU8cTsof1VE=    1.0      1
# 519762  iVgZutnakWInIdVj2fpLSo0F6Us335nB6Q5QIT4NtUU=    1.0      1
# 249711  KJ09JCOTaHI2xraFt7dUxtubGi6i6xXwNskLU1RNJ5M=    1.0      1
# 525222  j+cXPiok35Qt2mjsY12CJ84UOWQu1emkch2nkPClvz0=    1.0      1

# %%
os = all_df.loc[:,('os', 'click')]
os['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
os.groupby(['os'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#               os     click   count
# 6  Windows Phone  0.005780     173
# 7        android  0.001572     636
# 2          Linux  0.001083    1846
# 0        Android  0.000889  415074
# 4        Unknown  0.000697    4302
# 3           OS X  0.000683   13174
# 5        Windows  0.000618  176464
# 8            iOS  0.000284  349206
# 1     BlackBerry  0.000000       3
# 9           ipad  0.000000      31

# %%
dvt = all_df.loc[:,('deviceType', 'click')]
dvt['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
dvt.groupby(['deviceType'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#   deviceType     click   count
# 2     Tablet  0.000740   37825
# 0   Computer  0.000634  194017
# 1      Phone  0.000606  729615

# %%
pid = all_df.loc[:,('publisherId', 'click')]
pid['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
pid.groupby(['publisherId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#    publisherId     click  count
# 49  b92d94c79d  0.060044   1349
# 7   17ff555b8c  0.046369   1790
# 17  4113dd3c7b  0.036364    330
# 6   1669db331b  0.011176   4116
# 10  223727100b  0.008281   4106
# 21  483683f751  0.006410    156
# 50  ba76c28c2c  0.002397   2920
# 3   0e3a1a8bd8  0.001747   4006
# 33  721f3799d6  0.001701   4115
# 35  755dffed4e  0.001621    617

# %%
dcv = all_df.loc[:,('dclkVerticals', 'click')]
dcv['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
dcv.groupby(['dclkVerticals'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#                                          dclkVerticals  click  count
# 521  [{""""""""""""""""id"""""""""""""""":58,""""""...      1      1
# 0                                                   []      0    162
# 438  [{""""""""""""""""id"""""""""""""""":422,"""""...      0      1
# 431  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 432  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 433  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 434  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 435  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 436  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 437  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1

# %%
cid = all_df.loc[:,('campaignId', 'click')]
cid['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
cid.groupby(['campaignId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#     campaignId     click  count
# 35        4621  0.176471     17
# 24        4604  0.067961    309
# 45        4633  0.056604    742
# 29        4611  0.053333    600
# 27        4609  0.045899   1329
# 46        4634  0.039122   1048
# 9         4577  0.014706     68
# 16        4591  0.003161   6011
# 3         4540  0.002822   1063
# 47        4635  0.001876  25052

# %%
aid = all_df.loc[:,('advertiserId', 'click')]
aid['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
aid.groupby(['advertiserId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#     advertiserId     click   count
# 18           269  0.046369    1790
# 11           250  0.003161    6011
# 16           267  0.002822    1063
# 8            237  0.001670   12575
# 5            127  0.001602   19977
# 9            240  0.001356    3687
# 21           273  0.000897   14499
# 6            173  0.000817  179985
# 20           272  0.000780   15388
# 17           268  0.000703   11382

# %%
# Correlations to "click" are all very low.
# We should kick out some trash categories which has almost nothing to do with "click".
# Note the special case with "dclkVerticals", which has lots NaN entry. There are 2 ways to cope with it. Remove it or make the values 0 for NaN, otherwise 1.
# Categories that are probably no use( abs() < 0.01 ): deviceType, spaceType, dclkVerticals, adx, ip, os(?)

df_drop = all_df.drop(['deviceType', 'spaceType', 'dclkVerticals', 'adx', 'ip'], axis = 1).loc[:,:]
res_df = res_df.drop(['deviceType', 'spaceType', 'dclkVerticals', 'adx', 'ip'], axis = 1).loc[:,:]
res_df['click']=-1
print(res_df.size)
print(df_drop.size)
df_drop = df_drop.append(res_df)
# Out:
# 827040
# 7691656

# %%
df_final = pd.get_dummies(df_drop, columns=list(df_drop)[:-1])

# %%
 print(df_final['click'].value_counts())
# Out:
#  0    960864
# -1    103380
#  1       593
# Name: click, dtype: int64

# %%
pos = df_final[df_final['click'] == 1].sample(frac=1)
pos = np.split(pos, [df_final['click'].value_counts()[1] // 10 * 2], axis = 0)
train = pos[1]
# train = train.append([pos[1]] * 99, ignore_index=True)
test = pos[0]
neg = df_final[df_final['click'] == 0].sample(frac=1)
neg = np.split(neg, [df_final['click'].value_counts()[0] // 10 * 2], axis = 0)
train = train.append(neg[1], ignore_index=True).sample(frac=1)
test = test.append(neg[0], ignore_index=True).sample(frac=1)
X_train = train.drop(['click'], axis = 1)
Y_train = train['click']
X_test = test.drop(['click'], axis = 1)
Y_test = test['click']
sc = StandardScaler()
sc.fit(X_train)
X_trstd = sc.transform(X_train)
X_tsstd = sc.transform(X_test)

# %%
# PCA
cov_mat = np.cov(X_trstd.T)
eigen_vals, eigen_vecs = np.linalg.eig(cov_mat)
print('\nEigenvalues \n%s' % eigen_vals)
# Out:
# Eigenvalues
# [  6.19436663e+00 +0.00000000e+00j   5.18167120e+00 +0.00000000e+00j
#    5.12309167e+00 +0.00000000e+00j   4.60067412e+00 +0.00000000e+00j
#    4.36687916e+00 +0.00000000e+00j   3.34404751e+00 +0.00000000e+00j
#    3.26658885e+00 +0.00000000e+00j   3.20778200e+00 +0.00000000e+00j
#    3.21007234e+00 +0.00000000e+00j   3.07692670e+00 +0.00000000e+00j
#    3.05112933e+00 +0.00000000e+00j   3.02045887e+00 +0.00000000e+00j
#    3.00076490e+00 +0.00000000e+00j   2.97830520e+00 +0.00000000e+00j
#    2.96534389e+00 +0.00000000e+00j   2.95230205e+00 +0.00000000e+00j
#    2.92909038e+00 +0.00000000e+00j   2.86837370e+00 +0.00000000e+00j
#    2.86985226e+00 +0.00000000e+00j   2.80155575e+00 +0.00000000e+00j
#    2.73344316e+00 +0.00000000e+00j   2.67265626e+00 +0.00000000e+00j
#    2.68672680e+00 +0.00000000e+00j   2.53816187e+00 +0.00000000e+00j
#    2.49387148e+00 +0.00000000e+00j   2.44236625e+00 +0.00000000e+00j
#    2.30289997e+00 +0.00000000e+00j   2.28203394e+00 +0.00000000e+00j
#    2.27263991e+00 +0.00000000e+00j   2.21773771e+00 +0.00000000e+00j
#    2.19900038e+00 +0.00000000e+00j   2.17326229e+00 +0.00000000e+00j
#    2.18347622e+00 +0.00000000e+00j   2.11637395e+00 +0.00000000e+00j
#    1.45560197e+00 +0.00000000e+00j   1.48012322e+00 +0.00000000e+00j
#    1.53302964e+00 +0.00000000e+00j   1.51459855e+00 +0.00000000e+00j
#    1.60670877e+00 +0.00000000e+00j   1.63675304e+00 +0.00000000e+00j
#    1.65884568e+00 +0.00000000e+00j   1.66871710e+00 +0.00000000e+00j
#    1.68275665e+00 +0.00000000e+00j   1.71968681e+00 +0.00000000e+00j
#    1.70778290e+00 +0.00000000e+00j   1.88558355e+00 +0.00000000e+00j
#    2.08687294e+00 +0.00000000e+00j   2.07935702e+00 +0.00000000e+00j
#    1.92073280e+00 +0.00000000e+00j   2.07041984e+00 +0.00000000e+00j
#    1.94751021e+00 +0.00000000e+00j   2.05261791e+00 +0.00000000e+00j
#    2.04821106e+00 +0.00000000e+00j   2.04349059e+00 +0.00000000e+00j
#    2.03574090e+00 +0.00000000e+00j   2.03540108e+00 +0.00000000e+00j
#    2.03147341e+00 +0.00000000e+00j   1.96834791e+00 +0.00000000e+00j
#    2.02245293e+00 +0.00000000e+00j   1.97839439e+00 +0.00000000e+00j
#    2.01533598e+00 +0.00000000e+00j   2.01301366e+00 +0.00000000e+00j
#    2.01068821e+00 +0.00000000e+00j   1.98390502e+00 +0.00000000e+00j
#    1.98538506e+00 +0.00000000e+00j   1.99028614e+00 +0.00000000e+00j
#    1.98859501e+00 +0.00000000e+00j   1.98893558e+00 +0.00000000e+00j
#    2.00796760e+00 +0.00000000e+00j   1.99434313e+00 +0.00000000e+00j
#    1.99663902e+00 +0.00000000e+00j   2.00460406e+00 +0.00000000e+00j
#    2.00366478e+00 +0.00000000e+00j   2.00269562e+00 +0.00000000e+00j
#    1.99906048e+00 +0.00000000e+00j   1.99940003e+00 +0.00000000e+00j
#    2.00188326e+00 +0.00000000e+00j   2.00113169e+00 +0.00000000e+00j
#    2.00149623e+00 +0.00000000e+00j   1.41037386e+00 +0.00000000e+00j
#    1.39391955e+00 +0.00000000e+00j   1.35165849e+00 +0.00000000e+00j
#    1.32555789e+00 +0.00000000e+00j   1.30987469e+00 +0.00000000e+00j
#    1.31881994e+00 +0.00000000e+00j   1.27239823e+00 +0.00000000e+00j
#    1.26748473e+00 +0.00000000e+00j   1.25317785e+00 +0.00000000e+00j
#    1.21141125e+00 +0.00000000e+00j   1.19258392e+00 +0.00000000e+00j
#    1.18683554e+00 +0.00000000e+00j   1.99968728e+00 +0.00000000e+00j
#    2.00086665e+00 +0.00000000e+00j   2.00064056e+00 +0.00000000e+00j
#    2.00000316e+00 +0.00000000e+00j   2.00045858e+00 +0.00000000e+00j
#    2.00011355e+00 +0.00000000e+00j   2.00024831e+00 +0.00000000e+00j
#    2.00027093e+00 +0.00000000e+00j   3.96955351e-01 +0.00000000e+00j
#    4.75914000e-01 +0.00000000e+00j   5.22053838e-01 +0.00000000e+00j
#    5.24715588e-01 +0.00000000e+00j   5.09695850e-01 +0.00000000e+00j
#    5.89330805e-01 +0.00000000e+00j   6.01664842e-01 +0.00000000e+00j
#    6.26416693e-01 +0.00000000e+00j   6.43162775e-01 +0.00000000e+00j
#    6.45102339e-01 +0.00000000e+00j   6.66973755e-01 +0.00000000e+00j
#    7.04288350e-01 +0.00000000e+00j   7.37950562e-01 +0.00000000e+00j
#    7.55024812e-01 +0.00000000e+00j   7.67865642e-01 +0.00000000e+00j
#    1.17023981e+00 +0.00000000e+00j   1.13502690e+00 +0.00000000e+00j
#    8.57922802e-01 +0.00000000e+00j   8.92488373e-01 +0.00000000e+00j
#    8.96273591e-01 +0.00000000e+00j   8.83961411e-01 +0.00000000e+00j
#    9.11902031e-01 +0.00000000e+00j   1.11021791e+00 +0.00000000e+00j
#    1.09431075e+00 +0.00000000e+00j   1.08584461e+00 +0.00000000e+00j
#    1.10238146e+00 +0.00000000e+00j   1.10169207e+00 +0.00000000e+00j
#    9.27265119e-01 +0.00000000e+00j   9.32790439e-01 +0.00000000e+00j
#    1.07866869e+00 +0.00000000e+00j   1.07648564e+00 +0.00000000e+00j
#    1.07239245e+00 +0.00000000e+00j   9.42250839e-01 +0.00000000e+00j
#    9.46336019e-01 +0.00000000e+00j   9.47851122e-01 +0.00000000e+00j
#    1.06095156e+00 +0.00000000e+00j   1.05881348e+00 +0.00000000e+00j
#    9.56711251e-01 +0.00000000e+00j   9.59308960e-01 +0.00000000e+00j
#    9.61907865e-01 +0.00000000e+00j   9.68697764e-01 +0.00000000e+00j
#    9.76121111e-01 +0.00000000e+00j   9.79166097e-01 +0.00000000e+00j
#    1.05065168e+00 +0.00000000e+00j   9.84625586e-01 +0.00000000e+00j
#    1.04876899e+00 +0.00000000e+00j   1.04557836e+00 +0.00000000e+00j
#    1.04044311e+00 +0.00000000e+00j   1.03914321e+00 +0.00000000e+00j
#    1.03597341e+00 +0.00000000e+00j   1.03140181e+00 +0.00000000e+00j
#    1.02967549e+00 +0.00000000e+00j   1.02582019e+00 +0.00000000e+00j
#    1.02346177e+00 +0.00000000e+00j   1.01453889e+00 +0.00000000e+00j
#    1.01532404e+00 +0.00000000e+00j   1.02064153e+00 +0.00000000e+00j
#    1.01984369e+00 +0.00000000e+00j   1.01952383e+00 +0.00000000e+00j
#    9.86250571e-01 +0.00000000e+00j   9.86832297e-01 +0.00000000e+00j
#    9.89085512e-01 +0.00000000e+00j   9.91539617e-01 +0.00000000e+00j
#    1.01162907e+00 +0.00000000e+00j   1.01041387e+00 +0.00000000e+00j
#    1.00683568e+00 +0.00000000e+00j   1.00900951e+00 +0.00000000e+00j
#    1.00827239e+00 +0.00000000e+00j   1.49850270e-01 +0.00000000e+00j
#    1.18292439e-01 +0.00000000e+00j   9.94037641e-01 +0.00000000e+00j
#    9.95745952e-01 +0.00000000e+00j   9.96530605e-01 +0.00000000e+00j
#    1.00617952e+00 +0.00000000e+00j   1.00621357e+00 +0.00000000e+00j
#    1.00534394e+00 +0.00000000e+00j   1.00259726e+00 +0.00000000e+00j
#    1.00282929e+00 +0.00000000e+00j   1.00291719e+00 +0.00000000e+00j
#    1.00302066e+00 +0.00000000e+00j   1.00314639e+00 +0.00000000e+00j
#    1.00480548e+00 +0.00000000e+00j   1.00471760e+00 +0.00000000e+00j
#    1.00465666e+00 +0.00000000e+00j   1.00458263e+00 +0.00000000e+00j
#    1.00440271e+00 +0.00000000e+00j   1.00434812e+00 +0.00000000e+00j
#    1.00419789e+00 +0.00000000e+00j   1.00412685e+00 +0.00000000e+00j
#    1.00339389e+00 +0.00000000e+00j   1.00381972e+00 +0.00000000e+00j
#    1.00365897e+00 +0.00000000e+00j   1.00375836e+00 +0.00000000e+00j
#    1.00370909e+00 +0.00000000e+00j   4.79852478e-02 +0.00000000e+00j
#    4.10054893e-02 +0.00000000e+00j   9.97394364e-01 +0.00000000e+00j
#    9.98101435e-01 +0.00000000e+00j   9.98998011e-01 +0.00000000e+00j
#    1.00242473e+00 +0.00000000e+00j   1.00225395e+00 +0.00000000e+00j
#    1.00212023e+00 +0.00000000e+00j   1.00194832e+00 +0.00000000e+00j
#    1.00199138e+00 +0.00000000e+00j   1.00177897e+00 +0.00000000e+00j
#    1.00168255e+00 +0.00000000e+00j   1.00147518e+00 +0.00000000e+00j
#    1.00140860e+00 +0.00000000e+00j   1.00131115e+00 +0.00000000e+00j
#    1.00125831e+00 +0.00000000e+00j   1.00117769e+00 +0.00000000e+00j
#    1.00091700e+00 +0.00000000e+00j   1.00105489e+00 +0.00000000e+00j
#    1.00102260e+00 +0.00000000e+00j   3.87342280e-02 +0.00000000e+00j
#    3.47610446e-02 +0.00000000e+00j   3.26628756e-02 +0.00000000e+00j
#    9.99191233e-01 +0.00000000e+00j   9.99333675e-01 +0.00000000e+00j
#    1.00089290e+00 +0.00000000e+00j   1.00084967e+00 +0.00000000e+00j
#    1.00076826e+00 +0.00000000e+00j   1.00071804e+00 +0.00000000e+00j
#    1.00066506e+00 +0.00000000e+00j   1.00054297e+00 +0.00000000e+00j
#    1.00055680e+00 +0.00000000e+00j   1.00057861e+00 +0.00000000e+00j
#    1.00060762e+00 +0.00000000e+00j   1.97373954e-02 +0.00000000e+00j
#    9.99545360e-01 +0.00000000e+00j   9.99635755e-01 +0.00000000e+00j
#    9.99752839e-01 +0.00000000e+00j   1.00046370e+00 +0.00000000e+00j
#    1.00045044e+00 +0.00000000e+00j   1.00042301e+00 +0.00000000e+00j
#    1.00041452e+00 +0.00000000e+00j   1.00026827e+00 +0.00000000e+00j
#    1.00028817e+00 +0.00000000e+00j   1.00031196e+00 +0.00000000e+00j
#    1.00032312e+00 +0.00000000e+00j   1.00036426e+00 +0.00000000e+00j
#    1.00037263e+00 +0.00000000e+00j   1.16280684e-02 +0.00000000e+00j
#    6.76339248e-03 +0.00000000e+00j   9.99765550e-01 +0.00000000e+00j
#    9.99821044e-01 +0.00000000e+00j   9.99865078e-01 +0.00000000e+00j
#    1.00025347e+00 +0.00000000e+00j   1.00023513e+00 +0.00000000e+00j
#    1.00021852e+00 +0.00000000e+00j   1.00020117e+00 +0.00000000e+00j
#    1.00019436e+00 +0.00000000e+00j   1.00018258e+00 +0.00000000e+00j
#    1.00017611e+00 +0.00000000e+00j   1.00014070e+00 +0.00000000e+00j
#    1.00014378e+00 +0.00000000e+00j   1.00015166e+00 +0.00000000e+00j
#    1.00016538e+00 +0.00000000e+00j   1.00015813e+00 +0.00000000e+00j
#    4.84770936e-03 +0.00000000e+00j   2.31142354e-03 +0.00000000e+00j
#    2.16345797e-03 +0.00000000e+00j   9.99901018e-01 +0.00000000e+00j
#    9.99939630e-01 +0.00000000e+00j   1.00013296e+00 +0.00000000e+00j
#    1.00012184e+00 +0.00000000e+00j   1.00011088e+00 +0.00000000e+00j
#    1.00010336e+00 +0.00000000e+00j   1.00009735e+00 +0.00000000e+00j
#    1.00006791e+00 +0.00000000e+00j   1.00007038e+00 +0.00000000e+00j
#    1.00007418e+00 +0.00000000e+00j   1.00007883e+00 +0.00000000e+00j
#    1.00008200e+00 +0.00000000e+00j   1.00009053e+00 +0.00000000e+00j
#    1.00008806e+00 +0.00000000e+00j   1.96668312e-03 +0.00000000e+00j
#    1.82750664e-03 +0.00000000e+00j   9.99949756e-01 +0.00000000e+00j
#    1.00003568e+00 +0.00000000e+00j   1.00003909e+00 +0.00000000e+00j
#    1.00003971e+00 +0.00000000e+00j   1.00003939e+00 +0.00000000e+00j
#    1.00004461e+00 +0.00000000e+00j   1.00004902e+00 +0.00000000e+00j
#    1.00005041e+00 +0.00000000e+00j   1.00006296e+00 +0.00000000e+00j
#    1.00006150e+00 +0.00000000e+00j   1.00005424e+00 +0.00000000e+00j
#    1.00005669e+00 +0.00000000e+00j   1.00005824e+00 +0.00000000e+00j
#    1.00005754e+00 +0.00000000e+00j   1.01446804e-03 +0.00000000e+00j
#    9.12880244e-04 +0.00000000e+00j   5.71582012e-04 +0.00000000e+00j
#    1.00003721e+00 +0.00000000e+00j   1.00003550e+00 +0.00000000e+00j
#    1.00003125e+00 +0.00000000e+00j   1.00002945e+00 +0.00000000e+00j
#    1.00002736e+00 +0.00000000e+00j   1.00002714e+00 +0.00000000e+00j
#    1.00002603e+00 +0.00000000e+00j   1.00001585e+00 +0.00000000e+00j
#    1.00001668e+00 +0.00000000e+00j   1.00001682e+00 +0.00000000e+00j
#    1.00001821e+00 +0.00000000e+00j   1.00002103e+00 +0.00000000e+00j
#    1.00002270e+00 +0.00000000e+00j   1.00002259e+00 +0.00000000e+00j
#    2.18678968e-04 +0.00000000e+00j   9.84507369e-05 +0.00000000e+00j
#    1.00001367e+00 +0.00000000e+00j   1.00001322e+00 +0.00000000e+00j
#    1.00001265e+00 +0.00000000e+00j   1.00001231e+00 +0.00000000e+00j
#    1.00001183e+00 +0.00000000e+00j   1.00001087e+00 +0.00000000e+00j
#    1.00001047e+00 +0.00000000e+00j   1.00000936e+00 +0.00000000e+00j
#    1.00000909e+00 +0.00000000e+00j   1.00000873e+00 +0.00000000e+00j
#    1.00000814e+00 +0.00000000e+00j   1.00000794e+00 +0.00000000e+00j
#    1.00000733e+00 +0.00000000e+00j   1.00000726e+00 +0.00000000e+00j
#    1.00000688e+00 +0.00000000e+00j   1.00000649e+00 +0.00000000e+00j
#    1.00000639e+00 +0.00000000e+00j   1.00000596e+00 +0.00000000e+00j
#    1.00000603e+00 +0.00000000e+00j   5.01759435e-05 +0.00000000e+00j
#    1.00000608e+00 +0.00000000e+00j   1.00000572e+00 +0.00000000e+00j
#    1.00000552e+00 +0.00000000e+00j   1.00000505e+00 +0.00000000e+00j
#    1.00000500e+00 +0.00000000e+00j   1.00000481e+00 +0.00000000e+00j
#    1.00000471e+00 +0.00000000e+00j   1.00000445e+00 +0.00000000e+00j
#    1.00000441e+00 +0.00000000e+00j   1.00000418e+00 +0.00000000e+00j
#    1.00000414e+00 +0.00000000e+00j   1.00000380e+00 +0.00000000e+00j
#    1.00000374e+00 +0.00000000e+00j   1.00000358e+00 +0.00000000e+00j
#    1.00000353e+00 +0.00000000e+00j   1.00000344e+00 +0.00000000e+00j
#    1.00000330e+00 +0.00000000e+00j   1.00000321e+00 +0.00000000e+00j
#    1.00000312e+00 +0.00000000e+00j   1.00000310e+00 +0.00000000e+00j
#    1.00000292e+00 +0.00000000e+00j   1.00000282e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.54695276e-13 +0.00000000e+00j   1.27993571e-13 +0.00000000e+00j
#   -1.23737312e-13 +0.00000000e+00j  -9.79224359e-14 +0.00000000e+00j
#    9.59124045e-14 +0.00000000e+00j   9.21591656e-14 +0.00000000e+00j
#    7.85564325e-14 +0.00000000e+00j   7.91498437e-14 +0.00000000e+00j
#   -8.10633701e-14 +0.00000000e+00j  -7.77875839e-14 +0.00000000e+00j
#   -7.55904242e-14 +0.00000000e+00j   6.26917502e-14 +0.00000000e+00j
#    5.88693797e-14 +0.00000000e+00j  -5.63629778e-14 +0.00000000e+00j
#    4.65183706e-14 +0.00000000e+00j   4.15578707e-14 +0.00000000e+00j
#    3.70311815e-14 +0.00000000e+00j  -4.81592410e-14 +0.00000000e+00j
#   -4.76137775e-14 +0.00000000e+00j  -4.60106119e-14 +0.00000000e+00j
#   -4.49132817e-14 +0.00000000e+00j  -4.31177297e-14 +0.00000000e+00j
#    3.31339993e-14 +0.00000000e+00j   2.78266004e-14 +0.00000000e+00j
#   -3.69319539e-14 +0.00000000e+00j  -3.65028262e-14 +0.00000000e+00j
#   -3.58886913e-14 +0.00000000e+00j   2.33215181e-14 +0.00000000e+00j
#    2.07810347e-14 +0.00000000e+00j   1.73158549e-14 +0.00000000e+00j
#   -2.37297838e-14 +0.00000000e+00j  -2.27337538e-14 +0.00000000e+00j
#   -2.21892447e-14 +0.00000000e+00j  -2.14317817e-14 +0.00000000e+00j
#   -1.94915325e-14 +0.00000000e+00j   1.36619865e-14 +0.00000000e+00j
#   -1.71684832e-14 +0.00000000e+00j  -2.18548927e-14 +0.00000000e+00j
#   -2.20132940e-14 +0.00000000e+00j   1.13144290e-14 +0.00000000e+00j
#    9.77203532e-15 +0.00000000e+00j  -1.48749654e-14 +0.00000000e+00j
#   -1.33620138e-14 +0.00000000e+00j  -1.14882168e-14 +0.00000000e+00j
#    7.48915579e-15 +0.00000000e+00j  -9.04810431e-15 +0.00000000e+00j
#   -1.01738553e-14 +0.00000000e+00j  -9.75842505e-15 +0.00000000e+00j
#   -8.11082484e-15 +0.00000000e+00j  -5.26272650e-15 +0.00000000e+00j
#    5.77602945e-15 +0.00000000e+00j   6.30643605e-15 +0.00000000e+00j
#    6.46302707e-15 +0.00000000e+00j   4.24499071e-15 +0.00000000e+00j
#   -3.23097064e-15 +0.00000000e+00j   2.34855457e-15 +0.00000000e+00j
#   -2.80203364e-15 +0.00000000e+00j  -2.39486182e-15 +0.00000000e+00j
#    1.65316604e-15 +0.00000000e+00j  -1.78558034e-15 +0.00000000e+00j
#    6.29903964e-16 +0.00000000e+00j  -6.89864327e-16 +0.00000000e+00j
#   -4.72796593e-16 +0.00000000e+00j   4.86979728e-16 +0.00000000e+00j
#    3.07259856e-16 +1.92845425e-16j   3.07259856e-16 -1.92845425e-16j
#   -2.95108183e-16 +1.59829968e-16j  -2.95108183e-16 -1.59829968e-16j
#   -3.52366726e-16 +0.00000000e+00j   3.47939088e-16 +8.22923938e-17j
#    3.47939088e-16 -8.22923938e-17j   3.36832989e-16 +0.00000000e+00j
#   -3.05466406e-16 +0.00000000e+00j  -1.07268496e-16 +2.36272828e-16j
#   -1.07268496e-16 -2.36272828e-16j   1.79782101e-16 +2.02068084e-16j
#    1.79782101e-16 -2.02068084e-16j   5.85523959e-17 +2.13633523e-16j
#    5.85523959e-17 -2.13633523e-16j  -2.39227810e-16 +0.00000000e+00j
#    1.92251177e-16 +5.60772595e-17j   1.92251177e-16 -5.60772595e-17j
#   -2.00753972e-16 +0.00000000e+00j  -2.54611235e-17 +1.48927754e-16j
#   -2.54611235e-17 -1.48927754e-16j  -1.69830741e-16 +6.07679630e-17j
#   -1.69830741e-16 -6.07679630e-17j   1.49210013e-16 +0.00000000e+00j
#   -1.11221787e-16 +4.87220802e-17j  -1.11221787e-16 -4.87220802e-17j
#    1.03069882e-16 +0.00000000e+00j  -4.14850103e-17 +3.46663652e-17j
#   -4.14850103e-17 -3.46663652e-17j   1.66908260e-17 +3.85424536e-17j
#    1.66908260e-17 -3.85424536e-17j   2.35559278e-17 +0.00000000e+00j
#   -2.35361860e-17 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.2)
X_trpca = pca.fit_transform(X_trstd)
X_tspca = pca.transform(X_tsstd)
pca.explained_variance_ratio_
# Out:
# array([ 0.01320759,  0.01104833,  0.01092342,  0.00980953,  0.00931103,
#         0.00713016,  0.006965  ,  0.0068445 ,  0.00683961,  0.0065606 ,
#         0.0065056 ,  0.0064402 ,  0.00639821,  0.00635032,  0.00632269,
#         0.00629488,  0.00624539,  0.00611908,  0.00611593,  0.00597346,
#         0.00582823,  0.00572862,  0.00569862,  0.00541185,  0.00531742,
#         0.0052076 ,  0.00491023,  0.00486574,  0.00484571,  0.00472865])

# %%
clf = RandomForestClassifier(n_estimators=100, n_jobs=-2, class_weight={0:1, 1:10})
clf.fit(X_trpca, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 10},
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=-2, oob_score=False,
#             random_state=None, verbose=0, warm_start=False)

# %%
tn, fp, fn, tp = confusion_matrix(clf.predict(X_tspca), Y_test).ravel()
(tn, fp, fn, tp)
# Out:
# (192043, 90, 129, 28)

# %%
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(clf.predict(X_tspca), Y_test))
# Out:
# 0.998861095221
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00    192133
#           1       0.24      0.18      0.20       157
#
# avg / total       1.00      1.00      1.00    192290

# %%
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
for f in range(X_tspca.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 60, df_final.columns[1:][f], importances[indices[f]]))
# Out:
#  1) spaceId_00a10127a9834bf3                                     0.084968
#  2) spaceId_00b07139e7c2469f                                     0.055834
#  3) spaceId_023fb23d52714e9e                                     0.051494
#  4) spaceId_03c1df85b408454d                                     0.046009
#  5) spaceId_04fcb658d5d546eb                                     0.039792
#  6) spaceId_05add4abe3ea46c8                                     0.038755
#  7) spaceId_06698a05389c416e                                     0.031363
#  8) spaceId_07266f676d684613                                     0.029103
#  9) spaceId_08716dcda11a4dca                                     0.027126
# 10) spaceId_0931c4b63d6c421e                                     0.026110
# 11) spaceId_0b60a577ef1b4907                                     0.025741
# 12) spaceId_0bde96c547ed4e07                                     0.025111
# 13) spaceId_0f8234666bfa42a4                                     0.024701
# 14) spaceId_0faa8f92844e49c0                                     0.023291
# 15) spaceId_10d7573588ac4fea                                     0.021455
# 16) spaceId_11550b3c773d493b                                     0.020481
# 17) spaceId_1268ef47194b4404                                     0.019512
# 18) spaceId_12b83249d39b4e94                                     0.019461
# 19) spaceId_12e4122a3a974681                                     0.017876
# 20) spaceId_1518c1359fc14af5                                     0.017171
# 21) spaceId_1545b4697b874fdc                                     0.016929
# 22) spaceId_1594dbbf247b46a1                                     0.015266
# 23) spaceId_16935bb933d54c9e                                     0.015190
# 24) spaceId_18c83c15a9424c80                                     0.015131
# 25) spaceId_1a2687687697428b                                     0.014858
# 26) spaceId_1b35be0e43ce4d40                                     0.014838
# 27) spaceId_1bbcbcd4f42e4a35                                     0.013530
# 28) spaceId_1bf0eeda8dde463f                                     0.013509
# 29) spaceId_1fbb301d837049ef                                     0.013506
# 30) spaceId_22332037104249df                                     0.012507
# 31) spaceId_23af0e5a83a44472                                     0.012265
# 32) spaceId_246534f932db4682                                     0.012251
# 33) spaceId_2739708f44dc45ab                                     0.012126
# 34) spaceId_2d9b5904cf6e4b8f                                     0.011578
# 35) spaceId_2e3a68f992914a8a                                     0.011433
# 36) spaceId_2e5076b15d7c436b                                     0.011418
# 37) spaceId_2e5784f5ac344cea                                     0.011293
# 38) spaceId_31e5a397d5b446d6                                     0.011158
# 39) spaceId_33544cecccd142ad                                     0.010986
# 40) spaceId_34feb672c81f4c46                                     0.010491
# 41) spaceId_364aa47586da4492                                     0.010323
# 42) spaceId_36fd15639f574c0e                                     0.010248
# 43) spaceId_374e32d17b9e4fbe                                     0.010086
# 44) spaceId_38252b6944874169                                     0.009992
# 45) spaceId_38a46a8bc50946ad                                     0.009788
# 46) spaceId_39bae4031f5749e5                                     0.009701
# 47) spaceId_3a6591b39dec42c2                                     0.009401
# 48) spaceId_3b14805c7c194740                                     0.009151
# 49) spaceId_40b16f9db806494f                                     0.008073
# 50) spaceId_41583267f1f748fc                                     0.007617

# %%
res_df = df_final[df_final['click'] == -1].sample(frac=1)
res_df = res_df.drop(['click'], axis = 1).loc[:,:]
X_resstd = sc.transform(res_df)

# %%
X_respca = pca.transform(X_resstd)
Y_result = clf.predict(X_tspca)

# %%
display(Y_result)
unq, cnt = np.unique(Y_result, return_counts=True)
dict(zip(unq, cnt))
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
# {0: 192133, 1: 157}

# %%
np.savetxt('resullt.csv', Y_result, fmt='%i', delimiter=',')

# %%
# LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=100)
X_trlda = lda.fit_transform(X_trstd, Y_train)
X_tslda = lda.transform(X_tsstd)
lda.explained_variance_ratio_

# %%
clf = RandomForestClassifier(n_estimators=50, n_jobs=-2, class_weight={0:1, 1:10})
clf.fit(X_trlda, Y_train)

# %%
tn, fp, fn, tp = confusion_matrix(clf.predict(X_tslda), Y_test).ravel()
(tn, fp, fn, tp)

# %%
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(clf.predict(X_tslda), Y_test))

# %%
pos = df_final[df_final['click'] == 1].sample(frac=1)
pos = np.split(pos, [df_final['click'].value_counts()[1] // 10 * 2], axis = 0)
train = pos[1]
# train = train.append([pos[1]] * 99, ignore_index=True)
test = pos[0]
neg = df_final[df_final['click'] == 0].sample(frac=1)
neg = np.split(neg, [df_final['click'].value_counts()[0] // 10 * 2], axis = 0)
train = train.append(neg[1], ignore_index=True).sample(frac=1)
test = test.append(neg[0], ignore_index=True).sample(frac=1)
X_train = train.drop(['click'], axis = 1)
Y_train = train['click']
X_test = test.drop(['click'], axis = 1)
Y_test = test['click']
sc = StandardScaler()
sc.fit(X_train)
X_trstd = sc.transform(X_train)
X_tsstd = sc.transform(X_test)
pca = PCA(n_components = 50)
X_trpca = pca.fit_transform(X_trstd)
X_tspca = pca.transform(X_tsstd)
pca.explained_variance_ratio_

# %%
param_grid = [
#     {'C': [0.01, 0.1, 1, 10, 100], 'kernel': ['linear']},
   {'C': [0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, (1 / 6)], 'kernel': ['rbf'], 'class_weight': [{0:1, 1:10}]},
#    {'C': [0.01, 0.1, 1, 10, 100], 'kernel': ['poly']},
#    {'C': [0.01, 0.1, 1, 10, 100], 'kernel': ['sigmoid']},
 ]
clf = GridSearchCV(SVC(), param_grid, n_jobs = -2, scoring = 'f1')
clf.fit(X_trpca, Y_train)

# %%
tn, fp, fn, tp = confusion_matrix(clf.predict(X_tspca), Y_test).ravel()
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(clf.predict(X_tspca), Y_test))

# %%
print(clf.cv_results_)
