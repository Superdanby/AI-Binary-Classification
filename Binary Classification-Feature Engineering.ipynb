# %%
import sys

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# %%
all_df = pd.read_csv('./TraData.csv', low_memory=False)

# %%
print(all_df.columns.values)
# Out:
# ['adx' 'spaceType' 'spaceId' 'spaceCat' 'adType' 'ip' 'os' 'deviceType'
#  'publisherId' 'dclkVerticals' 'campaignId' 'advertiserId' 'click']

# %%
# preview the data
all_df.head()
# Out:
#                                             adx spaceType           spaceId  \
# 0  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  4d5aa536cd864b8d
# 1  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  df29ee4288fb474d
# 2  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  fabac3bca4a34996
# 3  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  946bc0ae7ddf40a3
# 4  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  4d5aa536cd864b8d
#
#   spaceCat adType                                            ip       os  \
# 0    IAB12  [3,9]  7Rud97q13Yk7EGzprFZy33wjYC3lKOkoc1jboz3ToXQ=  Android
# 1  IAB14_1  [3,9]  HrAoePTXzwTq5HChEWEPrcUeiXOotVgU0eYw3LrI7Pk=  Android
# 2    IAB12  [3,9]  MLTk/b+dXbPnYVL1Y6rA0Q8yL23r4CYoGLTuB9L00v0=  Android
# 3    IAB12  [3,9]  s/8/MB6H7Z7v6OqfbEEIbf7umyGRoT8cQGsCEapBOb0=  Windows
# 4    IAB12  [3,9]  vIEzEmgA7srRUPf3VWgcNEYEwasLE8wwU/EcDNNnn44=  Android
#
#   deviceType publisherId dclkVerticals  campaignId  advertiserId  click
# 0      Phone  5ad6008850           NaN        4612           266      0
# 1      Phone  ca10720d22           NaN        4619           215      0
# 2      Phone  adcfa8aac4           NaN        4597           215      0
# 3   Computer  de184afdf3           NaN        4608           173      0
# 4      Phone  5ad6008850           NaN        4612           266      0

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961457 entries, 0 to 961456
# Data columns (total 13 columns):
# adx              961457 non-null object
# spaceType        961457 non-null object
# spaceId          961457 non-null object
# spaceCat         961286 non-null object
# adType           961457 non-null object
# ip               961457 non-null object
# os               961457 non-null object
# deviceType       961457 non-null object
# publisherId      961457 non-null object
# dclkVerticals    1218 non-null object
# campaignId       961457 non-null int64
# advertiserId     961457 non-null int64
# click            961457 non-null int64
# dtypes: int64(3), object(10)
# memory usage: 95.4+ MB

# %%
all_df.describe()
# Out:
#           campaignId   advertiserId          click
# count  961457.000000  961457.000000  961457.000000
# mean     4609.638719     195.320444       0.000617
# std        25.889714      68.249918       0.024827
# min      4506.000000      16.000000       0.000000
# 25%      4603.000000     127.000000       0.000000
# 50%      4612.000000     215.000000       0.000000
# 75%      4627.000000     266.000000       0.000000
# max      4636.000000     273.000000       1.000000

# %%
all_df.describe(include=['O'])
# Out:
#                                                  adx spaceType  \
# count                                         961457    961457
# unique                                             2         2
# top     oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site
# freq                                          960239    958317
#
#                  spaceId spaceCat  adType  \
# count             961457   961286  961457
# unique               309       22       6
# top     4d5aa536cd864b8d    IAB12   [3,9]
# freq              207461   709981  958295
#
#                                                   ip       os deviceType  \
# count                                         961457   961457     961457
# unique                                        714922       14          3
# top     47DEQpj8HBSa+/TImW+5JCeuQeRkm5NMpJWZG3hSuFU=  Android      Phone
# freq                                            4266   415074     729615
#
#        publisherId dclkVerticals
# count       961457          1218
# unique          62           651
# top     5ad6008850            []
# freq        574610           162

# %%
for x in all_df.columns.values:
    print(all_df[x].value_counts())
    print("\n")
# Out:
# oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=    960239
# CuXcT8n6P0sIIAJUDjlunuV0ZnzP7p3Xf1jHLo2OlOE=      1218
# Name: adx, dtype: int64
#
#
# site    958317
# app       3140
# Name: spaceType, dtype: int64
#
#
# 4d5aa536cd864b8d            207461
# c60bd9fe77034acf            100203
# df29ee4288fb474d             68067
# fa604d518ae1467e             67354
# b5c7401fdb844f88             51410
# cb4ebda0667a420c             47348
# d0850c0f52434b05             40352
# 1a2687687697428b             39181
# fabac3bca4a34996             28905
# 31e5a397d5b446d6             16626
# 44846a9be8b9491e             12054
# 5bf9d630c1d145ad             11984
# fdf13d0e67b2490f             11645
# c60975775c6f4777             11341
# 1594dbbf247b46a1             10994
# f70c5595c6384911             10189
# 39bae4031f5749e5              9947
# 81565d0bbb714164              9332
# 468208fd4f584df9              8315
# 885942723ca24daa              7663
# 9ea6db12e4af4782              6426
# 946bc0ae7ddf40a3              5920
# f84a62779b074594              5447
# 534d9328b73f497e              5036
# b59f386c0ff246c5              5029
# 86947281878143cc              4911
# fb3abfe6db644c52              4878
# e0fbf3b24e694090              4524
# 7343e878f5224c06              4488
# b57e3ec4507e4bf1              4428
#                              ...
# dcard.tw/3000600                 1
# cnyes.com/3000600                1
# df410f8a29234fb5                 1
# life.tw/3000250                  1
# nownews.com/600                  1
# horofriend88.com/3360280         1
# udn.com/3000600                  1
# pkget.com/4120280                1
# 524d13f27492492c                 1
# ipeen.com.tw/3000600             1
# a7accaba28104914                 1
# others/3680280                   1
# 10d7573588ac4fea                 1
# pixnet.net/3940280               1
# plurk.com/3360280                1
# others/3450280                   1
# others/3540280                   1
# blogspot.com/3360280             1
# 5fe1f2a237f946a8                 1
# others/3720280                   1
# 8a6096d978484f16                 1
# sina.com.tw/3000600              1
# others/3410280                   1
# taiwantour.info/3360280          1
# 1bf0eeda8dde463f                 1
# chinatimes.com/3000600           1
# cocomy.net/600                   1
# blogspot.tw/3360280              1
# sharetify.com/600                1
# others/3000250                   1
# Name: spaceId, Length: 309, dtype: int64
#
#
# IAB12       709981
# IAB14_1     104502
# IAB9_30      77573
# IAB17        17858
# IAB1         17701
# IAB19        11485
# IAB8         11046
# IAB18         5732
# IAB3          1875
# IAB9           772
# IAB20          717
# IAB22          692
# IAB7           455
# IAB19_18       367
# IAB13          164
# IAB1_1         161
# IAB2           117
# IAB16           66
# IAB10           17
# IAB15            2
# IAB4             2
# IAB11            1
# Name: spaceCat, dtype: int64
#
#
# [3,9]            958295
# [4]                1790
# [1,2,5,7]           770
# [1,2,5,6,7]         448
# [1,2,5,7,8]         105
# [1,2,5,6,7,8]        49
# Name: adType, dtype: int64
#
#
# 47DEQpj8HBSa+/TImW+5JCeuQeRkm5NMpJWZG3hSuFU=    4266
# sbBK8U1MoK6JstNasQEvbHU1Pt6n10SF1G5nL9Fhbp8=     289
# fRQJESJejmoqiBJSJtIB0c/AW15j6xJ/vPiwmTaa8nU=     272
# 04M932pgr5m//DUQ3wAr9yYWb63TCSGmTggOO0yTSdo=     227
# kCM/BZz7oMrVGqKhzs4o/uVhP5S0Oy9XriQtkZYc4Qg=     176
# aHSbS1cpmW/MQoqVIhyKFvv1VQTW694qET8S6Xv1tz0=     126
# +gd8TcpOI9eADHav1ezambW039D5kKtnexcsEVc+kPo=     114
# ftWDR+NTjsTC6spD/S0pqR37aRT8r8QBffU6CQh3qWg=     112
# lciLjvmu02Vn+p4tnzQVYEOgVFy1zMiUFxo94dlRoc4=     111
# DVX7KB6kIANx7NARHnfb174J/DlGyqb0SrChT7ipWmg=     109
# /DwR/mbuWi1ZN+aPZzXFMj+U8b9aI4mDgWusYjzVQn0=     104
# FwCQ0l5mv0PiAgG5EjFr6aoW8HF3TQmhEIo4c+qDvWQ=     103
# SYkOI1g/Y7/s5e1Kn6CPtmjIGK3Izgl2swpD8YN9ABU=     100
# VKHyn0REXQdb11c2bq15/7gzsrNc8SdQup5goNLdBxE=      99
# AW1C+SLZIuJsiU+jcnphjnBohfaTDMLmhvqXI2v1iS8=      96
# CZ+X5loG3Vy4NTR7A3+4ontb7xBSWvnu2l00Dwag5O0=      95
# uG3eLgSPjxsSmP4XzKd5SjhSlIQ1GjwESSMR5icxu6w=      95
# mVNZZjW4uT5cVvQynssebP4fuNBG7uGWLXheRZAdFvo=      94
# 7udWSjNikIPwp052b8afxnX8UiK806jiLBsRNXmh3pY=      93
# peEUwI9j53rzzCAnMtbtifU9z0YRZ4izxq3E/MqW1oI=      93
# 4MtEEzbdg3UYSO6l+AZFpCyl4EtGhYkopLOndR3e7co=      92
# pL3hJBssNrNcgguKi1uoUSUYzqzOzjOvMdqmeF6zf+o=      92
# j8DNqGZ/J2pcfjFA5iAsqFsOkU2FIChzljXlTwsOWXE=      92
# +3jaIoAJfqA7qDVI9DrpWzPdDGU11qvUBVhrwM3s3mY=      92
# PgrsJKeFhnoMdLNrLIgcAnvusFBeQ5goN3+oycvQCck=      92
# UlrEYDxp6E1ZV0OAiFgvZH3yDeLfocNe08Ynl4wyxkI=      92
# 74pEF9nf3CyDscF1r0JhEHWH3eV0vOps7FzJ4yKY2sQ=      90
# +gTVqQvIqEyMHul8vDLfyMrd4xyIk2eioxy3sNq+Q8c=      89
# WaptWIdROed1sdScNTXR2uaq1l/1G/1PuWWO7w7jazk=      89
# ZKhi9zWDcSWBWGrbqCe6ff0sORo2HyrxKLr5CfvGcrg=      88
#                                                 ...
# WUZOU8L14bKDOC4U/GRGI+JgJ6v+tGMzOXQ7k0XSajA=       1
# m4Mj1TriSKmbEWBPO4zd2/taaJwWZNdnfNWYzjgkDsw=       1
# 43wEHlnlqYZh7kWMo/20CECiupRUsHQOfbywkILQbXY=       1
# LZr46wYwcwKcNzpjjajoEdyo3nihj/fL/vwM0h0QoAk=       1
# wtJdJmNLnPq6NjBKjapmhebJ49ur8zdMdoCn4EAnpFk=       1
# YmOjxh8tlGM5P4cGqW5wnkRU10fIA4lsS7khCSlVVZs=       1
# HDBo2zOwhbnGrnBYZ3JJ6iYO1Q9jlX6bnwWVcOEqis0=       1
# tVblfh1zRily4nOfhHxAZgwbUaFuZd/BEM2I4V19Tdo=       1
# kHV3ScGJ/4la3U/WgqJ+vtKcgKl3+WWmpZ33JDf1WtA=       1
# MLSA2lsfY8yE4K72GNi355YoslRWP+/S20k8dTLKDws=       1
# 5UUDSoi7KHrB94r+bKOuVZ9BnpQh3XULFHcIKLniorU=       1
# QGSTYa7Tz5NyWni57CDOTh8krg+U8hqL+rUpZy8gy9o=       1
# T2mr9715lvuiWDBW8CSDUhRxSa8yW2EZtHvnGmn+UJY=       1
# 0L6r/PZlLJtiaF4+LnNpFVfYczd1DCKgRP6aMFi956M=       1
# SREbPRE7ZnUf47t9HON7I3mzDAFrzOQtWW0sNPHlWgw=       1
# LyN5sv3d3B0oYFN4qObbEVZo2UzrpqXqAsbCr+jK8kg=       1
# XpU7uQMSJFl++malBOVMk112OTLaV1taNfjiOgLo7Oo=       1
# CWKvIiPKJ4ycPepkRf7/5H4P3wtDgSCI2J6QpRTWGM4=       1
# 7yRVxHYO7zrR8hxnXWqpuUgMdxdFIpkfQjWAFLE0Rcw=       1
# G6qgXoBL4cBORyb5nFS6muVp8MxtVUV+/GKTEaKzpfc=       1
# xjKkXxgk1L5lntNldNrA2CZhAjopJiYNsHcChGEqkAw=       1
# qtT9zbXWNNtVCn1l0wKSGPwB2Aw/W94jPD0CAeYj5ug=       1
# d9HCAOyqQAOThe1mH6NtZ0pnra+IRi7up7RCRvgxbU4=       1
# 79IjmnKzrLKR3Wl7fJVUAb7+f6eO08CI4daNw5qeuKA=       1
# i6M1nyCGhb7lUSL9tF8SS87pwz7i40iySvdbIIJ8SUM=       1
# e7NSUCMEQkFvXOBRRMFUvyMr9k/HtUUroBS4iKVXHH4=       1
# X+hNYrFUjod3L2k6s932+wf0Y7rKIenKeMx7c0Jeet0=       1
# Bjkt6GlPyZNW1gG+8L53+3xi2Bed10k0CyGizxo2+Nk=       1
# E7HUQEAo/NeaCH2co8sxpxL31zZoZyTJNq+0bojh6JM=       1
# p4ndkCgXO/VtPIXsXUDFfuafpJHMRBpap4txbvEKQhM=       1
# Name: ip, Length: 714922, dtype: int64
#
#
# Android          415074
# iOS              349206
# Windows          176464
# OS X              13174
# Unknown            4302
# Linux              1846
# android             636
# windows             431
# Windows Phone       173
# iphone              103
# ipad                 31
# mac                   9
# others                5
# BlackBerry            3
# Name: os, dtype: int64
#
#
# Phone       729615
# Computer    194017
# Tablet       37825
# Name: deviceType, dtype: int64
#
#
# 5ad6008850     574610
# a3036f8e67      77543
# ca10720d22      73514
# adcfa8aac4      38852
# 7260f81d98      34541
# b690e780f0      23140
# 558fb820ae      17852
# fadcc2c833      15593
# 9f8830f7bf      11264
# 7747c99aa4      10409
# 7e3fee842e      10093
# 1e0ce0bc6c       7853
# de184afdf3       6711
# 4ce500f989d      6426
# 6986953953       6291
# c5fcab9794       5716
# 1669db331b       4116
# 721f3799d6       4115
# 223727100b       4106
# 0e3a1a8bd8       4006
# 58f8225958       3140
# ba76c28c2c       2920
# 17ff555b8c       1790
# 21910dc609       1786
# 6b52d2a6e8       1649
# bf0e29cd55       1580
# 26b5e4c061       1422
# 1073a27ffd       1415
# b92d94c79d       1349
# 4a101d0c29       1306
#                 ...
# 9dd3332fdc        919
# 755dffed4e        617
# a92833a3ef        484
# 4113dd3c7b        330
# 042f5cf04b        165
# 483683f751        156
# e99b6a548b        152
# 46c7f4c651        141
# 78d13f130c        123
# 4996d019b0        122
# b1892a47b3        119
# 5b1287fe69         97
# 0d4fb169f9         96
# a1af7f300f         80
# 492b25a971         63
# 445347f8e0         52
# 26579599ab         35
# 2c2f1d69de         32
# edf6bafad6         17
# 80cad8d6af         10
# c1393c1ab9          9
# cced0b5053          7
# c77d2964e5          5
# 57f5a2fd70          4
# 3720                2
# 3046                2
# 3640                1
# a25606c9b2          1
# 0b9b2e3c02          1
# 46cec11619f         1
# Name: publisherId, Length: 62, dtype: int64
#
#
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                     162
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                              115
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                   60
# [{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                  59
# [{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":182,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                             20
# [{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                   18
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                   16
# [{""""""""""""""""id"""""""""""""""":301,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":0.75}]                                                                                                                                                                                                                                                                                              14
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":317,""""""""""""""""weight"""""""""""""""":0.4148325},{""""""""""""""""id"""""""""""""""":284,""""""""""""""""weight"""""""""""""""":0.1754304},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.4097371}]                                                                                                     12
# [{""""""""""""""""id"""""""""""""""":231,""""""""""""""""weight"""""""""""""""":0.38738245},{""""""""""""""""id"""""""""""""""":926,""""""""""""""""weight"""""""""""""""":0.61261755}]                                                                                                                                                                                                                                                                                  9
# [{""""""""""""""""id"""""""""""""""":408,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                    9
# [{""""""""""""""""id"""""""""""""""":1379,""""""""""""""""weight"""""""""""""""":0.469151},{""""""""""""""""id"""""""""""""""":926,""""""""""""""""weight"""""""""""""""":0.530849}]                                                                                                                                                                                                                                                                                     8
# [{""""""""""""""""id"""""""""""""""":870,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                          6
# [{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                    6
# [{""""""""""""""""id"""""""""""""""":622,""""""""""""""""weight"""""""""""""""":0.32967845},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":182,""""""""""""""""weight"""""""""""""""":0.23015402},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.44016755}]                                                                                                   5
# [{""""""""""""""""id"""""""""""""""":211,""""""""""""""""weight"""""""""""""""":0.2741867},{""""""""""""""""id"""""""""""""""":1049,""""""""""""""""weight"""""""""""""""":0.22269844},{""""""""""""""""id"""""""""""""""":1410,""""""""""""""""weight"""""""""""""""":0.3137925},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":409,""""""""""""""""weight"""""""""""""""":0.18932238}]       4
# [{""""""""""""""""id"""""""""""""""":146,""""""""""""""""weight"""""""""""""""":0.76357377},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.23642623}]                                                                                                                                                                                                                                                                                  3
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.41626152},{""""""""""""""""id"""""""""""""""":1174,""""""""""""""""weight"""""""""""""""":0.5837385}]                                                                                                                                                                                                                                                                                  3
# [{""""""""""""""""id"""""""""""""""":203,""""""""""""""""weight"""""""""""""""":0.43641862},{""""""""""""""""id"""""""""""""""":1260,""""""""""""""""weight"""""""""""""""":0.5635814}]                                                                                                                                                                                                                                                                                  3
# [{""""""""""""""""id"""""""""""""""":1033,""""""""""""""""weight"""""""""""""""":0.28872415},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1261,""""""""""""""""weight"""""""""""""""":0.34691334},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.3643625}]                                                                                                 3
# [{""""""""""""""""id"""""""""""""""":525,""""""""""""""""weight"""""""""""""""":0.18400854},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.3274604},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.48853105}]                                                                                                    3
# [{""""""""""""""""id"""""""""""""""":396,""""""""""""""""weight"""""""""""""""":0.33365816},{""""""""""""""""id"""""""""""""""":16,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":259,""""""""""""""""weight"""""""""""""""":0.27461603},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.18912822},{""""""""""""""""id"""""""""""""""":409,""""""""""""""""weight"""""""""""""""":0.20259759}]         3
# [{""""""""""""""""id"""""""""""""""":420,""""""""""""""""weight"""""""""""""""":0.20161456},{""""""""""""""""id"""""""""""""""":1364,""""""""""""""""weight"""""""""""""""":0.18937801},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.1960302},{""""""""""""""""id"""""""""""""""":949,""""""""""""""""weight"""""""""""""""":0.41297722}]       3
# [{""""""""""""""""id"""""""""""""""":244,""""""""""""""""weight"""""""""""""""":0.23089036},{""""""""""""""""id"""""""""""""""":245,""""""""""""""""weight"""""""""""""""":0.7691096},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                              3
# [{""""""""""""""""id"""""""""""""""":1231,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                   2
# [{""""""""""""""""id"""""""""""""""":981,""""""""""""""""weight"""""""""""""""":0.3456819},{""""""""""""""""id"""""""""""""""":884,""""""""""""""""weight"""""""""""""""":0.22592428},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":119,""""""""""""""""weight"""""""""""""""":0.23575532}]                                                                                                    2
# [{""""""""""""""""id"""""""""""""""":485,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":531,""""""""""""""""weight"""""""""""""""":0.56615406},{""""""""""""""""id"""""""""""""""":84,""""""""""""""""weight"""""""""""""""":0.43384594}]                                                                                                                                                                                               2
# [{""""""""""""""""id"""""""""""""""":78,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                     2
# [{""""""""""""""""id"""""""""""""""":122,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":236,""""""""""""""""weight"""""""""""""""":0.71736246},{""""""""""""""""id"""""""""""""""":1526,""""""""""""""""weight"""""""""""""""":0.28263754}]                                                                                                                                                                                             2
# [{""""""""""""""""id"""""""""""""""":485,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                              2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# [{""""""""""""""""id"""""""""""""""":299,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1174,""""""""""""""""weight"""""""""""""""":0.61848205},{""""""""""""""""id"""""""""""""""":1271,""""""""""""""""weight"""""""""""""""":0.38151798}]                                                                                                                                                                                            1
# [{""""""""""""""""id"""""""""""""""":1211,""""""""""""""""weight"""""""""""""""":0.36907133},{""""""""""""""""id"""""""""""""""":238,""""""""""""""""weight"""""""""""""""":0.1754263},{""""""""""""""""id"""""""""""""""":1220,""""""""""""""""weight"""""""""""""""":0.25300062},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":626,""""""""""""""""weight"""""""""""""""":0.20250173}]       1
# [{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":93,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                1
# [{""""""""""""""""id"""""""""""""""":276,""""""""""""""""weight"""""""""""""""":0.23921023},{""""""""""""""""id"""""""""""""""":365,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1584,""""""""""""""""weight"""""""""""""""":0.36990386}]                                                                                                                                                                                             1
# [{""""""""""""""""id"""""""""""""""":498,""""""""""""""""weight"""""""""""""""":0.23830695},{""""""""""""""""id"""""""""""""""":737,""""""""""""""""weight"""""""""""""""":0.76169306},{""""""""""""""""id"""""""""""""""":582,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                              1
# [{""""""""""""""""id"""""""""""""""":907,""""""""""""""""weight"""""""""""""""":0.44268492},{""""""""""""""""id"""""""""""""""":122,""""""""""""""""weight"""""""""""""""":0.55731505},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                             1
# [{""""""""""""""""id"""""""""""""""":34,""""""""""""""""weight"""""""""""""""":0.54728365},{""""""""""""""""id"""""""""""""""":525,""""""""""""""""weight"""""""""""""""":0.25786713},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":182,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.1948492}]               1
# [{""""""""""""""""id"""""""""""""""":819,""""""""""""""""weight"""""""""""""""":0.21184276},{""""""""""""""""id"""""""""""""""":122,""""""""""""""""weight"""""""""""""""":0.24050026},{""""""""""""""""id"""""""""""""""":146,""""""""""""""""weight"""""""""""""""":0.24890658},{""""""""""""""""id"""""""""""""""":817,""""""""""""""""weight"""""""""""""""":0.2987504}]                                                                                             1
# [{""""""""""""""""id"""""""""""""""":317,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                               1
# [{""""""""""""""""id"""""""""""""""":78,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":310,""""""""""""""""weight"""""""""""""""":0.23170432},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":1141,""""""""""""""""weight"""""""""""""""":0.32563683},{""""""""""""""""id"""""""""""""""":271,""""""""""""""""weight"""""""""""""""":0.44265884}]              1
# [{""""""""""""""""id"""""""""""""""":1459,""""""""""""""""weight"""""""""""""""":0.3919089},{""""""""""""""""id"""""""""""""""":1457,""""""""""""""""weight"""""""""""""""":0.24896885},{""""""""""""""""id"""""""""""""""":107,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1163,""""""""""""""""weight"""""""""""""""":0.35912222}]                                                                                                 1
# [{""""""""""""""""id"""""""""""""""":422,""""""""""""""""weight"""""""""""""""":0.25599712},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":83,""""""""""""""""weight"""""""""""""""":0.2773635},{""""""""""""""""id"""""""""""""""":84,""""""""""""""""weight"""""""""""""""":0.21381558}]                                                                                                      1
# [{""""""""""""""""id"""""""""""""""":138,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                    1
# [{""""""""""""""""id"""""""""""""""":67,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":542,""""""""""""""""weight"""""""""""""""":0.18264684},{""""""""""""""""id"""""""""""""""":5058,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":5059,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":208,""""""""""""""""weight"""""""""""""""":0.31735316}]                    1
# [{""""""""""""""""id"""""""""""""""":145,""""""""""""""""weight"""""""""""""""":0.09771586},{""""""""""""""""id"""""""""""""""":238,""""""""""""""""weight"""""""""""""""":0.099279925},{""""""""""""""""id"""""""""""""""":5059,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":1220,""""""""""""""""weight"""""""""""""""":0.3030042},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0}]             1
# [{""""""""""""""""id"""""""""""""""":365,""""""""""""""""weight"""""""""""""""":0.32184887},{""""""""""""""""id"""""""""""""""":555,""""""""""""""""weight"""""""""""""""":0.17099586},{""""""""""""""""id"""""""""""""""":170,""""""""""""""""weight"""""""""""""""":0.2889451},{""""""""""""""""id"""""""""""""""":1504,""""""""""""""""weight"""""""""""""""":0.21821016}]                                                                                            1
# [{""""""""""""""""id"""""""""""""""":276,""""""""""""""""weight"""""""""""""""":0.6970336},{""""""""""""""""id"""""""""""""""":1527,""""""""""""""""weight"""""""""""""""":0.30296642}]                                                                                                                                                                                                                                                                                  1
# [{""""""""""""""""id"""""""""""""""":449,""""""""""""""""weight"""""""""""""""":0.25343707},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.31469873}]                                                                                                                                                                                              1
# [{""""""""""""""""id"""""""""""""""":179,""""""""""""""""weight"""""""""""""""":0.10436107},{""""""""""""""""id"""""""""""""""":542,""""""""""""""""weight"""""""""""""""":0.1452879},{""""""""""""""""id"""""""""""""""":5058,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":5059,""""""""""""""""weight"""""""""""""""":0.3377332},{""""""""""""""""id"""""""""""""""":208,""""""""""""""""weight"""""""""""""""":0.25035104}]        1
# [{""""""""""""""""id"""""""""""""""":886,""""""""""""""""weight"""""""""""""""":0.27382842},{""""""""""""""""id"""""""""""""""":1262,""""""""""""""""weight"""""""""""""""":0.23632412},{""""""""""""""""id"""""""""""""""":471,""""""""""""""""weight"""""""""""""""":0.48984745}]                                                                                                                                                                                      1
# [{""""""""""""""""id"""""""""""""""":1033,""""""""""""""""weight"""""""""""""""":0.2112599},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1193,""""""""""""""""weight"""""""""""""""":0.16704307},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.23355997},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.38813707}]      1
# [{""""""""""""""""id"""""""""""""""":245,""""""""""""""""weight"""""""""""""""":0.46027398},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":419,""""""""""""""""weight"""""""""""""""":0.2446745},{""""""""""""""""id"""""""""""""""":629,""""""""""""""""weight"""""""""""""""":0.29505152}]                                                                                                   1
# [{""""""""""""""""id"""""""""""""""":981,""""""""""""""""weight"""""""""""""""":0.18706033},{""""""""""""""""id"""""""""""""""":1541,""""""""""""""""weight"""""""""""""""":0.22343914},{""""""""""""""""id"""""""""""""""":237,""""""""""""""""weight"""""""""""""""":0.39915472},{""""""""""""""""id"""""""""""""""":825,""""""""""""""""weight"""""""""""""""":0.19034581}]                                                                                           1
# [{""""""""""""""""id"""""""""""""""":22,""""""""""""""""weight"""""""""""""""":0.30732352},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.41429508},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.2783814}]                                                                                                    1
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                               1
# [{""""""""""""""""id"""""""""""""""":264,""""""""""""""""weight"""""""""""""""":0.46725792},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":280,""""""""""""""""weight"""""""""""""""":0.19448636}]                                                                                                                                                                                              1
# [{""""""""""""""""id"""""""""""""""":179,""""""""""""""""weight"""""""""""""""":0.31423333},{""""""""""""""""id"""""""""""""""":1010,""""""""""""""""weight"""""""""""""""":0.42816016},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.2576065}]                                                                                                                                                                                       1
# [{""""""""""""""""id"""""""""""""""":1425,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":1163,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":904,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                         1
# [{""""""""""""""""id"""""""""""""""":58,""""""""""""""""weight"""""""""""""""":0.19176121},{""""""""""""""""id"""""""""""""""":401,""""""""""""""""weight"""""""""""""""":0.2627559},{""""""""""""""""id"""""""""""""""":558,""""""""""""""""weight"""""""""""""""":0.30711982},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.23836309}]         1
# [{""""""""""""""""id"""""""""""""""":105,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":447,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":1033,""""""""""""""""weight"""""""""""""""":0.24642146},{""""""""""""""""id"""""""""""""""":1021,""""""""""""""""weight"""""""""""""""":0.23874474},{""""""""""""""""id"""""""""""""""":41,""""""""""""""""weight"""""""""""""""":1.0}]                    1
# Name: dclkVerticals, Length: 651, dtype: int64
#
#
# 4612    199557
# 4636    189655
# 4610    129622
# 4597     67173
# 4596     59460
# 4608     48434
# 4506     26825
# 4626     26588
# 4635     25052
# 4619     23958
# 4603     19668
# 4574     19234
# 4607     15388
# 4632     14499
# 4627     12685
# 4571     12575
# 4575     11382
# 4558      9730
# 4625      8814
# 4518      7804
# 4591      6011
# 4602      4269
# 4630      3870
# 4620      3670
# 4631      3307
# 4600      1450
# 4609      1329
# 4613      1131
# 4601      1116
# 4540      1063
# 4634      1048
# 4629       857
# 4633       742
# 4611       600
# 4628       566
# 4599       461
# 4588       431
# 4589       374
# 4604       309
# 4586       175
# 4587       166
# 4578       158
# 4623       152
# 4577        68
# 4621        17
# 4590         4
# 4614         4
# 4521         4
# 4576         2
# Name: campaignId, dtype: int64
#
#
# 94     214707
# 266    199557
# 173    179985
# 215    151809
# 271     56687
# 260     34629
# 127     19977
# 96      19236
# 272     15388
# 273     14499
# 237     12575
# 268     11382
# 265      9730
# 246      7296
# 250      6011
# 240      3687
# 269      1790
# 251      1135
# 267      1063
# 41        158
# 64        152
# 16          4
# Name: advertiserId, dtype: int64
#
#
# 0    960864
# 1       593
# Name: click, dtype: int64

# %%
adx = all_df.loc[:,('adx', 'click')]
adx['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
adx.groupby(['adx'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False)
# Out:
#                                             adx     click   count
# 0  CuXcT8n6P0sIIAJUDjlunuV0ZnzP7p3Xf1jHLo2OlOE=  0.000821    1218
# 1  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=  0.000617  960239

# %%
spt = all_df.loc[:,('spaceType', 'click')]
spt['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
spt.groupby(['spaceType'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False)
# Out:
#   spaceType     click   count
# 1      site  0.000619  958317
# 0       app  0.000000    3140

# %%
spd = all_df.loc[:,('spaceId', 'click')]
spd['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
spd.groupby(['spaceId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#               spaceId     click  count
# 105  7f068f54a11e4d56  0.120120    666
# 54   44b9221f3c5742d3  0.056604    742
# 229  fbadbe0b84574e6c  0.047619     21
# 119  8e2e462a46df4439  0.039122   1048
# 129  a0faeba51aec4944  0.037007   1216
# 110  835efb3468c24b8d  0.036364    330
# 205  e53805fd0b0f45d7  0.026087    230
# 191  d9055bc9592444e0  0.013475   2449
# 1    00b07139e7c2469f  0.012500     80
# 85   655005bab3a9414d  0.011494     87

# %%
sct = all_df.loc[:,('spaceCat', 'click')]
sct['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
sct.groupby(['spaceCat'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#     spaceCat     click   count
# 11  IAB19_18  0.032698     367
# 13      IAB2  0.008547     117
# 4      IAB13  0.006098     164
# 0       IAB1  0.005423   17701
# 5    IAB14_1  0.001646  104502
# 19      IAB8  0.001630   11046
# 15     IAB22  0.001445     692
# 20      IAB9  0.001295     772
# 9      IAB18  0.001221    5732
# 8      IAB17  0.000616   17858

# %%
adt = all_df.loc[:,('adType', 'click')]
adt['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
adt.groupby(['adType'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#           adType     click   count
# 5            [4]  0.046369    1790
# 3      [1,2,5,7]  0.001299     770
# 4          [3,9]  0.000531  958295
# 0  [1,2,5,6,7,8]  0.000000      49
# 1    [1,2,5,6,7]  0.000000     448
# 2    [1,2,5,7,8]  0.000000     105

# %%
ip = all_df.loc[:,('ip', 'click')]
ip['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
ip.groupby(['ip'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#                                                   ip  click  count
# 329527  RQEikp3eipwmVfhBjwR/y8m01J0p+fF9emMe5RTfpHk=    1.0      1
# 185973  EbO84/dGxPzxlsuF3+hPNgD8fnedwD8Ec+xBgV9YpAg=    1.0      1
# 407741  YTKRw6rz7VigqF+GQwUOBljyNE7ceNJYS6PSp9a0KRg=    1.0      1
# 31205   0mCHfOi7qOiprjoJAUJ+KC+7tXKOp2FwHlAhhqCDLZE=    1.0      1
# 442421  bXhKxDjPEabRXQUAUsONNJ1jXPXfxWkYDnukForHGxU=    1.0      1
# 10156   +uAuX0tIXxhHu1d/7LFR8+oQU3PZ/xwJc64SY2lgJJ4=    1.0      1
# 575581  nVD+fv9iOmVE6sXQtaNdVa9OfU/gEKobWU8cTsof1VE=    1.0      1
# 519762  iVgZutnakWInIdVj2fpLSo0F6Us335nB6Q5QIT4NtUU=    1.0      1
# 249711  KJ09JCOTaHI2xraFt7dUxtubGi6i6xXwNskLU1RNJ5M=    1.0      1
# 525222  j+cXPiok35Qt2mjsY12CJ84UOWQu1emkch2nkPClvz0=    1.0      1

# %%
os = all_df.loc[:,('os', 'click')]
os['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
os.groupby(['os'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#               os     click   count
# 6  Windows Phone  0.005780     173
# 7        android  0.001572     636
# 2          Linux  0.001083    1846
# 0        Android  0.000889  415074
# 4        Unknown  0.000697    4302
# 3           OS X  0.000683   13174
# 5        Windows  0.000618  176464
# 8            iOS  0.000284  349206
# 1     BlackBerry  0.000000       3
# 9           ipad  0.000000      31

# %%
dvt = all_df.loc[:,('deviceType', 'click')]
dvt['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
dvt.groupby(['deviceType'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#   deviceType     click   count
# 2     Tablet  0.000740   37825
# 0   Computer  0.000634  194017
# 1      Phone  0.000606  729615

# %%
pid = all_df.loc[:,('publisherId', 'click')]
pid['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
pid.groupby(['publisherId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#    publisherId     click  count
# 49  b92d94c79d  0.060044   1349
# 7   17ff555b8c  0.046369   1790
# 17  4113dd3c7b  0.036364    330
# 6   1669db331b  0.011176   4116
# 10  223727100b  0.008281   4106
# 21  483683f751  0.006410    156
# 50  ba76c28c2c  0.002397   2920
# 3   0e3a1a8bd8  0.001747   4006
# 33  721f3799d6  0.001701   4115
# 35  755dffed4e  0.001621    617

# %%
dcv = all_df.loc[:,('dclkVerticals', 'click')]
dcv['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
dcv.groupby(['dclkVerticals'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#                                          dclkVerticals  click  count
# 521  [{""""""""""""""""id"""""""""""""""":58,""""""...      1      1
# 0                                                   []      0    162
# 438  [{""""""""""""""""id"""""""""""""""":422,"""""...      0      1
# 431  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 432  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 433  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 434  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 435  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 436  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 437  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1

# %%
cid = all_df.loc[:,('campaignId', 'click')]
cid['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
cid.groupby(['campaignId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#     campaignId     click  count
# 35        4621  0.176471     17
# 24        4604  0.067961    309
# 45        4633  0.056604    742
# 29        4611  0.053333    600
# 27        4609  0.045899   1329
# 46        4634  0.039122   1048
# 9         4577  0.014706     68
# 16        4591  0.003161   6011
# 3         4540  0.002822   1063
# 47        4635  0.001876  25052

# %%
aid = all_df.loc[:,('advertiserId', 'click')]
aid['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
aid.groupby(['advertiserId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#     advertiserId     click   count
# 18           269  0.046369    1790
# 11           250  0.003161    6011
# 16           267  0.002822    1063
# 8            237  0.001670   12575
# 5            127  0.001602   19977
# 9            240  0.001356    3687
# 21           273  0.000897   14499
# 6            173  0.000817  179985
# 20           272  0.000780   15388
# 17           268  0.000703   11382

# %%
# Correlations to "click" are all very low.
# We should kick out some trash categories which has almost nothing to do with "click".
# Note the special case with "dclkVerticals", which has lots NaN entry. There are 2 ways to cope with it. Remove it or make the values 0 for NaN, otherwise 1.
# Categories that are probably no use( abs() < 0.01 ): deviceType, spaceType, dclkVerticals, adx, ip, os(?)

df_drop = all_df.drop(['deviceType', 'spaceType', 'dclkVerticals', 'adx', 'ip'], axis = 1).loc[:,:]
df_drop.head(10)
# Out:
#             spaceId spaceCat adType       os publisherId  campaignId  \
# 0  4d5aa536cd864b8d    IAB12  [3,9]  Android  5ad6008850        4612
# 1  df29ee4288fb474d  IAB14_1  [3,9]  Android  ca10720d22        4619
# 2  fabac3bca4a34996    IAB12  [3,9]  Android  adcfa8aac4        4597
# 3  946bc0ae7ddf40a3    IAB12  [3,9]  Windows  de184afdf3        4608
# 4  4d5aa536cd864b8d    IAB12  [3,9]  Android  5ad6008850        4612
# 5  4d5aa536cd864b8d    IAB12  [3,9]      iOS  5ad6008850        4612
# 6  d0850c0f52434b05    IAB12  [3,9]  Windows  5ad6008850        4610
# 7  fa604d518ae1467e  IAB9_30  [3,9]  Android  a3036f8e67        4612
# 8  fabac3bca4a34996    IAB12  [3,9]  Windows  adcfa8aac4        4596
# 9  4d5aa536cd864b8d    IAB12  [3,9]      iOS  5ad6008850        4612
#
#    advertiserId  click
# 0           266      0
# 1           215      0
# 2           215      0
# 3           173      0
# 4           266      0
# 5           266      0
# 6           173      0
# 7           266      0
# 8           215      0
# 9           266      0

# %%
df_final = pd.get_dummies(df_drop, columns=list(df_drop)[:-1])

# %%
 print(df_final['click'].value_counts())
# Out:
# 0    960864
# 1       593
# Name: click, dtype: int64

# %%
pos = df_final[df_final['click'] == 1].sample(frac=1)
pos = np.split(pos, [df_final['click'].value_counts()[1] // 10 * 2], axis = 0)
train = pos[1]
# train = train.append([pos[1]] * 99, ignore_index=True)
test = pos[0]
neg = df_final[df_final['click'] == 0].sample(frac=1)
neg = np.split(neg, [df_final['click'].value_counts()[0] // 10 * 2], axis = 0)
train = train.append(neg[1], ignore_index=True).sample(frac=1)
test = test.append(neg[0], ignore_index=True).sample(frac=1)
X_train = train.drop(['click'], axis = 1)
Y_train = train['click']
X_test = test.drop(['click'], axis = 1)
Y_test = test['click']
sc = StandardScaler()
sc.fit(X_train)
X_trstd = sc.transform(X_train)
X_tsstd = sc.transform(X_test)

# %%
# PCA
cov_mat = np.cov(X_trstd.T)
eigen_vals, eigen_vecs = np.linalg.eig(cov_mat)
print('\nEigenvalues \n%s' % eigen_vals)
# Out:
# Eigenvalues
# [  6.19790905e+00 +0.00000000e+00j   5.18568908e+00 +0.00000000e+00j
#    5.13773711e+00 +0.00000000e+00j   4.74982910e+00 +0.00000000e+00j
#    4.36651904e+00 +0.00000000e+00j   3.34452197e+00 +0.00000000e+00j
#    3.26500301e+00 +0.00000000e+00j   3.20287597e+00 +0.00000000e+00j
#    3.21624622e+00 +0.00000000e+00j   3.07712514e+00 +0.00000000e+00j
#    3.05101008e+00 +0.00000000e+00j   3.02063546e+00 +0.00000000e+00j
#    3.00074237e+00 +0.00000000e+00j   2.97725608e+00 +0.00000000e+00j
#    2.96673835e+00 +0.00000000e+00j   2.95874296e+00 +0.00000000e+00j
#    2.92811414e+00 +0.00000000e+00j   2.86512463e+00 +0.00000000e+00j
#    2.86883020e+00 +0.00000000e+00j   2.80641765e+00 +0.00000000e+00j
#    2.73923480e+00 +0.00000000e+00j   2.67672871e+00 +0.00000000e+00j
#    2.68681102e+00 +0.00000000e+00j   2.53577104e+00 +0.00000000e+00j
#    2.52750979e+00 +0.00000000e+00j   2.44336155e+00 +0.00000000e+00j
#    2.28166280e+00 +0.00000000e+00j   2.26957377e+00 +0.00000000e+00j
#    2.24337928e+00 +0.00000000e+00j   2.21706557e+00 +0.00000000e+00j
#    2.19862982e+00 +0.00000000e+00j   2.18383719e+00 +0.00000000e+00j
#    2.17479742e+00 +0.00000000e+00j   2.11474990e+00 +0.00000000e+00j
#    2.08594429e+00 +0.00000000e+00j   2.07756122e+00 +0.00000000e+00j
#    2.06996258e+00 +0.00000000e+00j   2.02308416e+00 +0.00000000e+00j
#    2.05349110e+00 +0.00000000e+00j   2.03154552e+00 +0.00000000e+00j
#    2.04785643e+00 +0.00000000e+00j   2.04396178e+00 +0.00000000e+00j
#    2.03691629e+00 +0.00000000e+00j   2.03756430e+00 +0.00000000e+00j
#    1.88580614e+00 +0.00000000e+00j   1.92046317e+00 +0.00000000e+00j
#    1.94897763e+00 +0.00000000e+00j   1.96967735e+00 +0.00000000e+00j
#    1.97875970e+00 +0.00000000e+00j   1.98118859e+00 +0.00000000e+00j
#    2.01650127e+00 +0.00000000e+00j   2.01337563e+00 +0.00000000e+00j
#    1.98755783e+00 +0.00000000e+00j   1.98872230e+00 +0.00000000e+00j
#    2.00999511e+00 +0.00000000e+00j   2.00906877e+00 +0.00000000e+00j
#    1.99132879e+00 +0.00000000e+00j   1.99244309e+00 +0.00000000e+00j
#    1.99367250e+00 +0.00000000e+00j   1.99543581e+00 +0.00000000e+00j
#    1.99725915e+00 +0.00000000e+00j   2.00435292e+00 +0.00000000e+00j
#    2.00375574e+00 +0.00000000e+00j   2.00293209e+00 +0.00000000e+00j
#    2.00193292e+00 +0.00000000e+00j   2.00164187e+00 +0.00000000e+00j
#    1.99929425e+00 +0.00000000e+00j   2.00124821e+00 +0.00000000e+00j
#    1.99968759e+00 +0.00000000e+00j   2.00084946e+00 +0.00000000e+00j
#    2.00000944e+00 +0.00000000e+00j   2.00063468e+00 +0.00000000e+00j
#    2.00013269e+00 +0.00000000e+00j   2.00023947e+00 +0.00000000e+00j
#    2.00029843e+00 +0.00000000e+00j   2.00040146e+00 +0.00000000e+00j
#    2.00037502e+00 +0.00000000e+00j   1.61076085e+00 +0.00000000e+00j
#    1.63920560e+00 +0.00000000e+00j   1.67526559e+00 +0.00000000e+00j
#    1.68506265e+00 +0.00000000e+00j   1.70546008e+00 +0.00000000e+00j
#    1.73089130e+00 +0.00000000e+00j   1.72400241e+00 +0.00000000e+00j
#    1.53407378e+00 +0.00000000e+00j   1.52521087e+00 +0.00000000e+00j
#    1.51065755e+00 +0.00000000e+00j   1.38249108e+00 +0.00000000e+00j
#    1.26729801e+00 +0.00000000e+00j   1.33530641e+00 +0.00000000e+00j
#    1.32099876e+00 +0.00000000e+00j   1.30549335e+00 +0.00000000e+00j
#    1.29886583e+00 +0.00000000e+00j   1.30222891e+00 +0.00000000e+00j
#    1.31421066e+00 +0.00000000e+00j   1.25102600e+00 +0.00000000e+00j
#    1.20809262e+00 +0.00000000e+00j   1.19302126e+00 +0.00000000e+00j
#    1.18922000e+00 +0.00000000e+00j   1.18470261e+00 +0.00000000e+00j
#    3.73770503e-01 +0.00000000e+00j   4.78777430e-01 +0.00000000e+00j
#    4.87585563e-01 +0.00000000e+00j   5.21311658e-01 +0.00000000e+00j
#    5.37239430e-01 +0.00000000e+00j   5.55539167e-01 +0.00000000e+00j
#    6.07302907e-01 +0.00000000e+00j   6.36613994e-01 +0.00000000e+00j
#    6.46537174e-01 +0.00000000e+00j   6.49971811e-01 +0.00000000e+00j
#    7.07623777e-01 +0.00000000e+00j   7.20384351e-01 +0.00000000e+00j
#    7.69404811e-01 +0.00000000e+00j   8.03257166e-01 +0.00000000e+00j
#    8.13298047e-01 +0.00000000e+00j   8.59287011e-01 +0.00000000e+00j
#    1.15405083e+00 +0.00000000e+00j   1.13323487e+00 +0.00000000e+00j
#    1.11177838e+00 +0.00000000e+00j   1.10087789e+00 +0.00000000e+00j
#    1.50408359e-01 +0.00000000e+00j   8.87447626e-01 +0.00000000e+00j
#    8.88687349e-01 +0.00000000e+00j   8.95721271e-01 +0.00000000e+00j
#    8.95603041e-01 +0.00000000e+00j   1.10381707e+00 +0.00000000e+00j
#    1.09705146e+00 +0.00000000e+00j   1.09155645e+00 +0.00000000e+00j
#    9.24741018e-01 +0.00000000e+00j   1.08508889e+00 +0.00000000e+00j
#    1.07927142e+00 +0.00000000e+00j   1.07356512e+00 +0.00000000e+00j
#    9.34554913e-01 +0.00000000e+00j   1.06161133e+00 +0.00000000e+00j
#    9.43193628e-01 +0.00000000e+00j   9.45812792e-01 +0.00000000e+00j
#    1.05619371e+00 +0.00000000e+00j   1.05319093e+00 +0.00000000e+00j
#    9.54309451e-01 +0.00000000e+00j   9.57120410e-01 +0.00000000e+00j
#    9.60648490e-01 +0.00000000e+00j   1.04501069e+00 +0.00000000e+00j
#    1.04160987e+00 +0.00000000e+00j   1.04003390e+00 +0.00000000e+00j
#    1.03777336e+00 +0.00000000e+00j   1.22787096e-01 +0.00000000e+00j
#    4.12678702e-02 +0.00000000e+00j   3.54282923e-02 +0.00000000e+00j
#    3.58238109e-02 +0.00000000e+00j   3.34416040e-02 +0.00000000e+00j
#    2.75851043e-02 +0.00000000e+00j   9.67921800e-01 +0.00000000e+00j
#    9.72423744e-01 +0.00000000e+00j   9.75081148e-01 +0.00000000e+00j
#    1.03112053e+00 +0.00000000e+00j   9.79121684e-01 +0.00000000e+00j
#    1.02914907e+00 +0.00000000e+00j   1.02566965e+00 +0.00000000e+00j
#    1.02457307e+00 +0.00000000e+00j   1.02351001e+00 +0.00000000e+00j
#    9.84633124e-01 +0.00000000e+00j   9.85432325e-01 +0.00000000e+00j
#    1.02071523e+00 +0.00000000e+00j   1.01925919e+00 +0.00000000e+00j
#    1.01880431e+00 +0.00000000e+00j   9.88150209e-01 +0.00000000e+00j
#    9.89143999e-01 +0.00000000e+00j   1.01576454e+00 +0.00000000e+00j
#    1.01464448e+00 +0.00000000e+00j   9.92141307e-01 +0.00000000e+00j
#    1.01176070e+00 +0.00000000e+00j   9.93247219e-01 +0.00000000e+00j
#    1.01043190e+00 +0.00000000e+00j   9.94620215e-01 +0.00000000e+00j
#    1.00879325e+00 +0.00000000e+00j   1.00831634e+00 +0.00000000e+00j
#    1.00667675e+00 +0.00000000e+00j   1.00607529e+00 +0.00000000e+00j
#    1.00574996e+00 +0.00000000e+00j   1.00500835e+00 +0.00000000e+00j
#    1.00493029e+00 +0.00000000e+00j   1.00476793e+00 +0.00000000e+00j
#    1.00467173e+00 +0.00000000e+00j   1.00450337e+00 +0.00000000e+00j
#    1.00442973e+00 +0.00000000e+00j   2.06390977e-02 +0.00000000e+00j
#    1.16583121e-02 +0.00000000e+00j   5.58743108e-03 +0.00000000e+00j
#    3.31307292e-03 +0.00000000e+00j   9.96326873e-01 +0.00000000e+00j
#    9.97637894e-01 +0.00000000e+00j   9.98375259e-01 +0.00000000e+00j
#    1.00429862e+00 +0.00000000e+00j   1.00420654e+00 +0.00000000e+00j
#    1.00414930e+00 +0.00000000e+00j   9.98736114e-01 +0.00000000e+00j
#    1.00374388e+00 +0.00000000e+00j   1.00367270e+00 +0.00000000e+00j
#    1.00366152e+00 +0.00000000e+00j   1.00340349e+00 +0.00000000e+00j
#    1.00328263e+00 +0.00000000e+00j   1.00309676e+00 +0.00000000e+00j
#    1.00300035e+00 +0.00000000e+00j   1.00292126e+00 +0.00000000e+00j
#    1.00276733e+00 +0.00000000e+00j   9.99124990e-01 +0.00000000e+00j
#    1.00240838e+00 +0.00000000e+00j   1.00234517e+00 +0.00000000e+00j
#    9.99301301e-01 +0.00000000e+00j   1.00216009e+00 +0.00000000e+00j
#    1.00205184e+00 +0.00000000e+00j   1.00195405e+00 +0.00000000e+00j
#    1.00187316e+00 +0.00000000e+00j   1.00175124e+00 +0.00000000e+00j
#    1.00170532e+00 +0.00000000e+00j   1.00161667e+00 +0.00000000e+00j
#    1.00138529e+00 +0.00000000e+00j   1.00140201e+00 +0.00000000e+00j
#    1.00120569e+00 +0.00000000e+00j   1.00109241e+00 +0.00000000e+00j
#    1.00102200e+00 +0.00000000e+00j   1.00097992e+00 +0.00000000e+00j
#    1.00093458e+00 +0.00000000e+00j   1.00090026e+00 +0.00000000e+00j
#    1.00084941e+00 +0.00000000e+00j   1.00076865e+00 +0.00000000e+00j
#    2.48610397e-03 +0.00000000e+00j   2.07121618e-03 +0.00000000e+00j
#    1.73803623e-03 +0.00000000e+00j   1.72266719e-03 +0.00000000e+00j
#    9.95039885e-04 +0.00000000e+00j   7.57026390e-04 +0.00000000e+00j
#    5.40293396e-04 +0.00000000e+00j   9.99550019e-01 +0.00000000e+00j
#    9.99573854e-01 +0.00000000e+00j   9.99626044e-01 +0.00000000e+00j
#    1.00070316e+00 +0.00000000e+00j   9.99719482e-01 +0.00000000e+00j
#    1.00068053e+00 +0.00000000e+00j   1.00060102e+00 +0.00000000e+00j
#    1.00059033e+00 +0.00000000e+00j   1.00054449e+00 +0.00000000e+00j
#    9.99814338e-01 +0.00000000e+00j   1.00049002e+00 +0.00000000e+00j
#    1.00046333e+00 +0.00000000e+00j   9.99868033e-01 +0.00000000e+00j
#    1.00042292e+00 +0.00000000e+00j   1.00040218e+00 +0.00000000e+00j
#    1.00036692e+00 +0.00000000e+00j   1.00035851e+00 +0.00000000e+00j
#    1.00033982e+00 +0.00000000e+00j   1.00031994e+00 +0.00000000e+00j
#    1.00031475e+00 +0.00000000e+00j   1.00029375e+00 +0.00000000e+00j
#    1.00027273e+00 +0.00000000e+00j   1.00026606e+00 +0.00000000e+00j
#    1.00021662e+00 +0.00000000e+00j   1.00020235e+00 +0.00000000e+00j
#    1.00020100e+00 +0.00000000e+00j   1.00018840e+00 +0.00000000e+00j
#    1.00018554e+00 +0.00000000e+00j   1.00018053e+00 +0.00000000e+00j
#    1.00016245e+00 +0.00000000e+00j   1.00015639e+00 +0.00000000e+00j
#    1.00014211e+00 +0.00000000e+00j   1.00014440e+00 +0.00000000e+00j
#    9.99905852e-01 +0.00000000e+00j   9.99937127e-01 +0.00000000e+00j
#    9.99944615e-01 +0.00000000e+00j   1.00013502e+00 +0.00000000e+00j
#    1.00011761e+00 +0.00000000e+00j   1.00011371e+00 +0.00000000e+00j
#    1.00011033e+00 +0.00000000e+00j   1.00010150e+00 +0.00000000e+00j
#    1.00009851e+00 +0.00000000e+00j   1.00009482e+00 +0.00000000e+00j
#    1.00009067e+00 +0.00000000e+00j   1.00008167e+00 +0.00000000e+00j
#    1.00007903e+00 +0.00000000e+00j   1.00007341e+00 +0.00000000e+00j
#    1.00007052e+00 +0.00000000e+00j   1.00006816e+00 +0.00000000e+00j
#    1.00006653e+00 +0.00000000e+00j   1.00006265e+00 +0.00000000e+00j
#    1.00006191e+00 +0.00000000e+00j   1.00005977e+00 +0.00000000e+00j
#    1.00005648e+00 +0.00000000e+00j   1.00004887e+00 +0.00000000e+00j
#    1.00004818e+00 +0.00000000e+00j   1.00004348e+00 +0.00000000e+00j
#    1.00004294e+00 +0.00000000e+00j   1.00004263e+00 +0.00000000e+00j
#    1.00004104e+00 +0.00000000e+00j   1.00003847e+00 +0.00000000e+00j
#    1.00003620e+00 +0.00000000e+00j   1.00003293e+00 +0.00000000e+00j
#    1.00003357e+00 +0.00000000e+00j   1.00003063e+00 +0.00000000e+00j
#    1.00002772e+00 +0.00000000e+00j   1.00002878e+00 +0.00000000e+00j
#    1.00002442e+00 +0.00000000e+00j   1.00002198e+00 +0.00000000e+00j
#    1.00002126e+00 +0.00000000e+00j   1.00002301e+00 +0.00000000e+00j
#    1.00001905e+00 +0.00000000e+00j   1.00001847e+00 +0.00000000e+00j
#    1.00001715e+00 +0.00000000e+00j   1.00001664e+00 +0.00000000e+00j
#    1.00001564e+00 +0.00000000e+00j   1.00001503e+00 +0.00000000e+00j
#    1.00001455e+00 +0.00000000e+00j   1.00001389e+00 +0.00000000e+00j
#    1.00001202e+00 +0.00000000e+00j   1.00001096e+00 +0.00000000e+00j
#    1.00001038e+00 +0.00000000e+00j   1.00000979e+00 +0.00000000e+00j
#    1.00000933e+00 +0.00000000e+00j   1.00000915e+00 +0.00000000e+00j
#    1.00000860e+00 +0.00000000e+00j   1.00000869e+00 +0.00000000e+00j
#    1.00000800e+00 +0.00000000e+00j   1.00000777e+00 +0.00000000e+00j
#    1.00000756e+00 +0.00000000e+00j   1.00000708e+00 +0.00000000e+00j
#    1.00000681e+00 +0.00000000e+00j   1.00000665e+00 +0.00000000e+00j
#    1.00000644e+00 +0.00000000e+00j   1.00000631e+00 +0.00000000e+00j
#    1.00000601e+00 +0.00000000e+00j   1.00000577e+00 +0.00000000e+00j
#    1.00000568e+00 +0.00000000e+00j   1.00000532e+00 +0.00000000e+00j
#    1.00000512e+00 +0.00000000e+00j   1.00000494e+00 +0.00000000e+00j
#    1.00000488e+00 +0.00000000e+00j   1.00000464e+00 +0.00000000e+00j
#    1.00000449e+00 +0.00000000e+00j   1.00000441e+00 +0.00000000e+00j
#    1.00000422e+00 +0.00000000e+00j   1.00000394e+00 +0.00000000e+00j
#    1.00000281e+00 +0.00000000e+00j   1.00000286e+00 +0.00000000e+00j
#    1.00000296e+00 +0.00000000e+00j   1.00000308e+00 +0.00000000e+00j
#    1.00000371e+00 +0.00000000e+00j   1.00000318e+00 +0.00000000e+00j
#    1.00000325e+00 +0.00000000e+00j   1.00000331e+00 +0.00000000e+00j
#    1.00000342e+00 +0.00000000e+00j   1.00000350e+00 +0.00000000e+00j
#    1.00000360e+00 +0.00000000e+00j   9.31241835e-05 +0.00000000e+00j
#    8.01481437e-05 +0.00000000e+00j   5.44643377e-05 +0.00000000e+00j
#    1.00000272e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#   -1.73983177e-13 +0.00000000e+00j  -7.93282323e-14 +0.00000000e+00j
#   -5.47531726e-14 +0.00000000e+00j   6.04697773e-14 +0.00000000e+00j
#    4.87933371e-14 +0.00000000e+00j   4.67874197e-14 +0.00000000e+00j
#    4.38977837e-14 +0.00000000e+00j  -3.87760292e-14 +0.00000000e+00j
#    3.06491711e-14 +0.00000000e+00j   2.95481262e-14 +0.00000000e+00j
#    2.76658743e-14 +0.00000000e+00j   2.56983578e-14 +0.00000000e+00j
#   -3.34233589e-14 +0.00000000e+00j  -3.08668473e-14 +0.00000000e+00j
#   -2.95834785e-14 +0.00000000e+00j   1.97442982e-14 +0.00000000e+00j
#   -2.53903368e-14 +0.00000000e+00j   1.54296402e-14 +0.00000000e+00j
#    1.55518436e-14 +0.00000000e+00j  -2.19464771e-14 +0.00000000e+00j
#   -2.06051839e-14 +0.00000000e+00j   1.08900828e-14 +0.00000000e+00j
#    1.03616073e-14 +0.00000000e+00j  -1.81306060e-14 +0.00000000e+00j
#   -1.75720151e-14 +0.00000000e+00j  -1.67912810e-14 +0.00000000e+00j
#    8.64107682e-15 +0.00000000e+00j  -1.51952719e-14 +0.00000000e+00j
#   -1.40909363e-14 +0.00000000e+00j  -1.41301979e-14 +0.00000000e+00j
#   -1.29850470e-14 +1.71971134e-17j  -1.29850470e-14 -1.71971134e-17j
#   -1.30804822e-14 +0.00000000e+00j  -1.17427771e-14 +0.00000000e+00j
#   -1.05939848e-14 +0.00000000e+00j  -9.56694780e-15 +0.00000000e+00j
#    4.91052573e-15 +0.00000000e+00j   4.60497318e-15 +0.00000000e+00j
#   -8.80812749e-15 +0.00000000e+00j  -8.69209196e-15 +0.00000000e+00j
#   -7.67145447e-15 +0.00000000e+00j   3.97849027e-15 +0.00000000e+00j
#    3.64913857e-15 +0.00000000e+00j   3.21136401e-15 +0.00000000e+00j
#   -5.90778545e-15 +0.00000000e+00j  -5.52940885e-15 +0.00000000e+00j
#    2.62917038e-15 +0.00000000e+00j  -4.84432820e-15 +0.00000000e+00j
#    2.13420838e-15 +0.00000000e+00j  -4.26484108e-15 +0.00000000e+00j
#   -4.05577923e-15 +0.00000000e+00j  -3.84988631e-15 +0.00000000e+00j
#   -2.92242397e-15 +0.00000000e+00j  -3.32462508e-15 +2.86337791e-17j
#   -3.32462508e-15 -2.86337791e-17j  -2.13860075e-15 +0.00000000e+00j
#    1.63916880e-15 +0.00000000e+00j  -1.06831497e-15 +0.00000000e+00j
#   -6.63071996e-16 +0.00000000e+00j   4.66296914e-16 +0.00000000e+00j
#   -4.39226662e-16 +0.00000000e+00j  -3.81450099e-16 +1.87436738e-16j
#   -3.81450099e-16 -1.87436738e-16j   3.94031909e-16 +9.85560064e-17j
#    3.94031909e-16 -9.85560064e-17j   3.90893798e-16 +0.00000000e+00j
#    2.53349244e-16 +1.93472869e-16j   2.53349244e-16 -1.93472869e-16j
#   -3.25065154e-16 +1.46795703e-17j  -3.25065154e-16 -1.46795703e-17j
#   -2.85088556e-16 +8.86980273e-17j  -2.85088556e-16 -8.86980273e-17j
#    3.08665361e-16 +0.00000000e+00j   2.95535235e-16 +0.00000000e+00j
#    5.03842672e-17 +2.28099991e-16j   5.03842672e-17 -2.28099991e-16j
#    1.34884953e-16 +1.70097212e-16j   1.34884953e-16 -1.70097212e-16j
#    2.08294481e-16 +0.00000000e+00j   1.92978826e-16 +5.77999623e-17j
#    1.92978826e-16 -5.77999623e-17j  -1.92511941e-16 +9.92631096e-17j
#   -1.92511941e-16 -9.92631096e-17j   2.69591693e-17 +1.70146493e-16j
#    2.69591693e-17 -1.70146493e-16j   8.04405852e-17 +8.58117687e-17j
#    8.04405852e-17 -8.58117687e-17j  -9.59918649e-17 +1.18167561e-16j
#   -9.59918649e-17 -1.18167561e-16j  -1.67704974e-17 +1.20731795e-16j
#   -1.67704974e-17 -1.20731795e-16j   6.34631842e-17 +2.20637683e-17j
#    6.34631842e-17 -2.20637683e-17j  -9.40483714e-17 +5.61361752e-17j
#   -9.40483714e-17 -5.61361752e-17j  -5.45183575e-17 +1.74053032e-17j
#   -5.45183575e-17 -1.74053032e-17j  -8.16114783e-17 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    1.00000260e+00 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.2)
X_trpca = pca.fit_transform(X_trstd)
X_tspca = pca.transform(X_tsstd)
pca.explained_variance_ratio_
# Out:
# array([ 0.01324338,  0.01108052,  0.01097806,  0.01014919,  0.00933016,
#         0.00714641,  0.00697649,  0.00687231,  0.00684374,  0.00657505,
#         0.00651924,  0.00645434,  0.00641183,  0.00636165,  0.00633918,
#         0.00632209,  0.00625665,  0.00612997,  0.00612205,  0.00599661,
#         0.00585306,  0.00574104,  0.0057195 ,  0.00541831,  0.00540065,
#         0.00522085,  0.00487534,  0.00484951,  0.00479354,  0.00473731])

# %%
clf = RandomForestClassifier(n_estimators=100, n_jobs=-2, class_weight={0:1, 1:10})
clf.fit(X_trpca, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 10},
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=-2, oob_score=False,
#             random_state=None, verbose=0, warm_start=False)

# %%
tn, fp, fn, tp = confusion_matrix(clf.predict(X_tspca), Y_test).ravel()
(tn, fp, fn, tp)
# Out:
# (192050, 97, 122, 21)

# %%
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(clf.predict(X_tspca), Y_test))
# Out:
# 0.998861095221
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00    192147
#           1       0.18      0.15      0.16       143
#
# avg / total       1.00      1.00      1.00    192290

# %%
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
for f in range(X_tspca.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 60, df_final.columns[1:][f], importances[indices[f]]))
# Out:
#  1) spaceId_00a10127a9834bf3                                     0.086213
#  2) spaceId_00b07139e7c2469f                                     0.071868
#  3) spaceId_023fb23d52714e9e                                     0.059086
#  4) spaceId_03c1df85b408454d                                     0.054293
#  5) spaceId_04fcb658d5d546eb                                     0.053679
#  6) spaceId_05add4abe3ea46c8                                     0.044924
#  7) spaceId_06698a05389c416e                                     0.042610
#  8) spaceId_07266f676d684613                                     0.038042
#  9) spaceId_08716dcda11a4dca                                     0.036984
# 10) spaceId_0931c4b63d6c421e                                     0.033599
# 11) spaceId_0b60a577ef1b4907                                     0.031943
# 12) spaceId_0bde96c547ed4e07                                     0.031437
# 13) spaceId_0f8234666bfa42a4                                     0.030748
# 14) spaceId_0faa8f92844e49c0                                     0.030385
# 15) spaceId_10d7573588ac4fea                                     0.026586
# 16) spaceId_11550b3c773d493b                                     0.024015
# 17) spaceId_1268ef47194b4404                                     0.023833
# 18) spaceId_12b83249d39b4e94                                     0.023830
# 19) spaceId_12e4122a3a974681                                     0.023318
# 20) spaceId_1518c1359fc14af5                                     0.023271
# 21) spaceId_1545b4697b874fdc                                     0.022886
# 22) spaceId_1594dbbf247b46a1                                     0.022861
# 23) spaceId_16935bb933d54c9e                                     0.022672
# 24) spaceId_18c83c15a9424c80                                     0.021034
# 25) spaceId_1a2687687697428b                                     0.020992
# 26) spaceId_1b35be0e43ce4d40                                     0.020918
# 27) spaceId_1bbcbcd4f42e4a35                                     0.020364
# 28) spaceId_1bf0eeda8dde463f                                     0.019899
# 29) spaceId_1fbb301d837049ef                                     0.019053
# 30) spaceId_22332037104249df                                     0.018657

# %%
# LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=0.2)
X_trlda = lda.fit_transform(X_trstd, Y_train)
X_tslda = lda.transform(X_tsstd)
lda.explained_variance_ratio_
# Out:
# /home/danny/Github/AI-Binary-Classification/venv/lib64/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-1e9410c8c5af> in <module>()
#       2 from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
#       3 lda = LinearDiscriminantAnalysis(n_components=0.2)
# ----> 4 X_trlda = lda.fit_transform(X_trstd, Y_train)
#       5 X_tslda = lda.transform(X_tsstd)
#       6 lda.explained_variance_ratio_
#
# ~/Github/AI-Binary-Classification/venv/lib64/python3.6/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
# --> 520             return self.fit(X, y, **fit_params).transform(X)
#     521
#     522
#
# ~/Github/AI-Binary-Classification/venv/lib64/python3.6/site-packages/sklearn/discriminant_analysis.py in fit(self, X, y)
#     453             if self.shrinkage is not None:
#     454                 raise NotImplementedError('shrinkage not supported')
# --> 455             self._solve_svd(X, y)
#     456         elif self.solver == 'lsqr':
#     457             self._solve_lsqr(X, y, shrinkage=self.shrinkage)
#
# ~/Github/AI-Binary-Classification/venv/lib64/python3.6/site-packages/sklearn/discriminant_analysis.py in _solve_svd(self, X, y)
#     400
#     401         self.explained_variance_ratio_ = (S**2 / np.sum(
# --> 402             S**2))[:self._max_components]
#     403         rank = np.sum(S > self.tol * S[0])
#     404         self.scalings_ = np.dot(scalings, V.T[:, :rank])
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
clf = RandomForestClassifier(n_estimators=100, n_jobs=-2, class_weight={0:1, 1:10})
clf.fit(X_trlda, Y_train)

# %%
tn, fp, fn, tp = confusion_matrix(clf.predict(X_tslda), Y_test).ravel()
(tn, fp, fn, tp)

# %%
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(clf.predict(X_tslda), Y_test))

# %%
param_grid = [
#     {'C': [0.01, 0.1, 1, 10, 100], 'kernel': ['linear']},
   {'C': [0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, (1 / 6)], 'kernel': ['rbf']},
#    {'C': [0.01, 0.1, 1, 10, 100], 'kernel': ['poly']},
#    {'C': [0.01, 0.1, 1, 10, 100], 'kernel': ['sigmoid']},
 ]
clf = GridSearchCV(SVC(), param_grid, n_jobs = -2, scoring = 'f1')
clf.fit(X_trstd, Y_train)

# %%
tn, fp, fn, tp = confusion_matrix(clf.predict(X_tsstd), Y_test).ravel()
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(clf.predict(X_tsstd), Y_test))

# %%
# expectation: doesn't work
ppn = Perceptron(max_iter = 100, eta0 = 0.1, n_jobs = -2, penalty = 'l2')
ppn.fit(X_trpca, Y_train)

# %%
tn, fp, fn, tp = confusion_matrix(ppn.predict(X_tspca), Y_test).ravel()
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(ppn.predict(X_tspca), Y_test))

# %%
lr = LogisticRegression(C=100, penalty = 'l2')
lr.fit(X_trpca, Y_train)

# %%
tn, fp, fn, tp = confusion_matrix(lr.predict(X_tspca), Y_test).ravel()
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(lr.predict(X_tspca), Y_test))

# %%
knn = KNeighborsClassifier(n_neighbors = 5, p = 2, metric='minkowski', n_jobs=-2)
knn.fit(X_train, Y_train)

# %%
tn, fp, fn, tp = confusion_matrix(knn.predict(X_test), Y_test).ravel()
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(knn.predict(X_test), Y_test))
