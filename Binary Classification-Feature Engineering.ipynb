# %%
import sys

# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# %%
all_df = pd.read_csv('./TraData.csv', low_memory=False)

# %%
print(all_df.columns.values)
# Out:
# ['adx' 'spaceType' 'spaceId' 'spaceCat' 'adType' 'ip' 'os' 'deviceType'
#  'publisherId' 'dclkVerticals' 'campaignId' 'advertiserId' 'click']

# %%
# preview the data
all_df.head()
# Out:
#                                             adx spaceType           spaceId  \
# 0  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  4d5aa536cd864b8d
# 1  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  df29ee4288fb474d
# 2  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  fabac3bca4a34996
# 3  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  946bc0ae7ddf40a3
# 4  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site  4d5aa536cd864b8d
#
#   spaceCat adType                                            ip       os  \
# 0    IAB12  [3,9]  7Rud97q13Yk7EGzprFZy33wjYC3lKOkoc1jboz3ToXQ=  Android
# 1  IAB14_1  [3,9]  HrAoePTXzwTq5HChEWEPrcUeiXOotVgU0eYw3LrI7Pk=  Android
# 2    IAB12  [3,9]  MLTk/b+dXbPnYVL1Y6rA0Q8yL23r4CYoGLTuB9L00v0=  Android
# 3    IAB12  [3,9]  s/8/MB6H7Z7v6OqfbEEIbf7umyGRoT8cQGsCEapBOb0=  Windows
# 4    IAB12  [3,9]  vIEzEmgA7srRUPf3VWgcNEYEwasLE8wwU/EcDNNnn44=  Android
#
#   deviceType publisherId dclkVerticals  campaignId  advertiserId  click
# 0      Phone  5ad6008850           NaN        4612           266      0
# 1      Phone  ca10720d22           NaN        4619           215      0
# 2      Phone  adcfa8aac4           NaN        4597           215      0
# 3   Computer  de184afdf3           NaN        4608           173      0
# 4      Phone  5ad6008850           NaN        4612           266      0

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961457 entries, 0 to 961456
# Data columns (total 13 columns):
# adx              961457 non-null object
# spaceType        961457 non-null object
# spaceId          961457 non-null object
# spaceCat         961286 non-null object
# adType           961457 non-null object
# ip               961457 non-null object
# os               961457 non-null object
# deviceType       961457 non-null object
# publisherId      961457 non-null object
# dclkVerticals    1218 non-null object
# campaignId       961457 non-null int64
# advertiserId     961457 non-null int64
# click            961457 non-null int64
# dtypes: int64(3), object(10)
# memory usage: 95.4+ MB

# %%
all_df.describe()
# Out:
#           campaignId   advertiserId          click
# count  961457.000000  961457.000000  961457.000000
# mean     4609.638719     195.320444       0.000617
# std        25.889714      68.249918       0.024827
# min      4506.000000      16.000000       0.000000
# 25%      4603.000000     127.000000       0.000000
# 50%      4612.000000     215.000000       0.000000
# 75%      4627.000000     266.000000       0.000000
# max      4636.000000     273.000000       1.000000

# %%
all_df.describe(include=['O'])
# Out:
#                                                  adx spaceType  \
# count                                         961457    961457
# unique                                             2         2
# top     oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=      site
# freq                                          960239    958317
#
#                  spaceId spaceCat  adType  \
# count             961457   961286  961457
# unique               309       22       6
# top     4d5aa536cd864b8d    IAB12   [3,9]
# freq              207461   709981  958295
#
#                                                   ip       os deviceType  \
# count                                         961457   961457     961457
# unique                                        714922       14          3
# top     47DEQpj8HBSa+/TImW+5JCeuQeRkm5NMpJWZG3hSuFU=  Android      Phone
# freq                                            4266   415074     729615
#
#        publisherId dclkVerticals
# count       961457          1218
# unique          62           651
# top     5ad6008850            []
# freq        574610           162

# %%
for x in all_df.columns.values:
    print(all_df[x].value_counts())
    print("\n")
# Out:
# oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=    960239
# CuXcT8n6P0sIIAJUDjlunuV0ZnzP7p3Xf1jHLo2OlOE=      1218
# Name: adx, dtype: int64
#
#
# site    958317
# app       3140
# Name: spaceType, dtype: int64
#
#
# 4d5aa536cd864b8d              207461
# c60bd9fe77034acf              100203
# df29ee4288fb474d               68067
# fa604d518ae1467e               67354
# b5c7401fdb844f88               51410
# cb4ebda0667a420c               47348
# d0850c0f52434b05               40352
# 1a2687687697428b               39181
# fabac3bca4a34996               28905
# 31e5a397d5b446d6               16626
# 44846a9be8b9491e               12054
# 5bf9d630c1d145ad               11984
# fdf13d0e67b2490f               11645
# c60975775c6f4777               11341
# 1594dbbf247b46a1               10994
# f70c5595c6384911               10189
# 39bae4031f5749e5                9947
# 81565d0bbb714164                9332
# 468208fd4f584df9                8315
# 885942723ca24daa                7663
# 9ea6db12e4af4782                6426
# 946bc0ae7ddf40a3                5920
# f84a62779b074594                5447
# 534d9328b73f497e                5036
# b59f386c0ff246c5                5029
# 86947281878143cc                4911
# fb3abfe6db644c52                4878
# e0fbf3b24e694090                4524
# 7343e878f5224c06                4488
# b57e3ec4507e4bf1                4428
#                                ...
# d18e1090fb9e465f                   1
# xuite.net/3360280                  1
# cnyes.com/3000600                  1
# pixnet.net/3940280                 1
# a7accaba28104914                   1
# koreastardaily.com/3360280         1
# technews.tw/600                    1
# others/7400300                     1
# fun01.cc/3360280                   1
# chinatimes.com/3000600             1
# others/4100280                     1
# others/3000250                     1
# blogspot.tw/3360280                1
# others/4120280                     1
# ettoday.net/3000250                1
# blogspot.com/3360280               1
# others/3410280                     1
# taiwantour.info/3360280            1
# bsxsw.com/3360280                  1
# life.tw/3000250                    1
# 96f1f5e50cae429b                   1
# others/3680280                     1
# 1bf0eeda8dde463f                   1
# others/3920280                     1
# 524d13f27492492c                   1
# cocomy.net/600                     1
# techbang.com/3360280               1
# df410f8a29234fb5                   1
# stargogo.com/600                   1
# sina.com.tw/3000600                1
# Name: spaceId, Length: 309, dtype: int64
#
#
# IAB12       709981
# IAB14_1     104502
# IAB9_30      77573
# IAB17        17858
# IAB1         17701
# IAB19        11485
# IAB8         11046
# IAB18         5732
# IAB3          1875
# IAB9           772
# IAB20          717
# IAB22          692
# IAB7           455
# IAB19_18       367
# IAB13          164
# IAB1_1         161
# IAB2           117
# IAB16           66
# IAB10           17
# IAB4             2
# IAB15            2
# IAB11            1
# Name: spaceCat, dtype: int64
#
#
# [3,9]            958295
# [4]                1790
# [1,2,5,7]           770
# [1,2,5,6,7]         448
# [1,2,5,7,8]         105
# [1,2,5,6,7,8]        49
# Name: adType, dtype: int64
#
#
# 47DEQpj8HBSa+/TImW+5JCeuQeRkm5NMpJWZG3hSuFU=    4266
# sbBK8U1MoK6JstNasQEvbHU1Pt6n10SF1G5nL9Fhbp8=     289
# fRQJESJejmoqiBJSJtIB0c/AW15j6xJ/vPiwmTaa8nU=     272
# 04M932pgr5m//DUQ3wAr9yYWb63TCSGmTggOO0yTSdo=     227
# /sDQ5JMcWm6MzWLfAbuFkL0fWnFAqW1OrSND2SpLhHE=       1
# bpgKSC5HR6MUg8tcEndTKkQa5Wg6/QY/HXXL7qzCtpI=       1
# X7dhoTGadIGQhXdhLfrqSiE5FZMN3z9PVCmW+wNu3K0=       1
# jiII6HXGJOUTH9uzVUAZA7iDWILgqT//135uW1cuqzA=       1
# spAMCBWWHSzWjh0h9dGRd6lUTKyHT612XojmkG2J/k4=       1
# eSzUG11KSjPA0iIoSUSI3nbI4iK5OBxHYog5uxckt7U=       1
# rg2nTRBrUo3ZTxP5SCoGRiR4yHauC80orKLVl6WLXfk=       1
# Z/Z0ovH5snLuj3lS6bk63ugF0MvL9FNmRsxmjMk5tR0=       1
# Cf4iyrVoHq0LEa8Rx+9+NQvrMQyCHOIBIAW2YUUVY80=       1
# F47i6rRpBGXQUzGzLmGWpEXJnElYuG88RNUvP75Jsak=       1
# vBUfjl7so1L06+wP8X5hrQOIKSA9zlThmmEnf9TLgQs=       1
# 800WBGbLrPIPECS1Jj56g2Lwp/dwIGj9fb/3GPfWqU0=       1
# HDWzw7zvVuesisgfyBkzRPu7ACPq0caMLGqIBZHj7ac=       1
# 7rPqRHPeytwMnNO7JFoPW1JmT/SqE+TCNbpnx6XuP9g=       1
# 8twmGkajMUbR2mkeYN0pTex3FRDd4IpP7r2nZcPlOAc=       1
# 9H/IVLyVXIlxE5nXuQA1iGHlSIbeWMR41ThAZ1wL0WI=       1
# 6vDG0Kzz6jwcP/WowVuPoELKK/PF3b1l18b8nX9/HOA=       1
# /6/lqiwrhSdiUeCrooDmyaLbP8VsmipfUowpU1OQKZ8=       1
# yRfsUd2AYgc+ax2VsWRDhXf/iTl+bI3trnINTWSGJBM=       1
# rhLgf50+J84zb2TlZTobNnvBYb8NIJfpzfqVRD6E7/Q=       1
# yzxLrmT91ChbEqCOfYpbTEQqYMp/I6Ve3vcCXauGv7Y=       1
# 0gg5zbYsErSC8TzuuH+B00oukAGx7fcVXQGHMmncCig=       1
# Name: ip, Length: 714922, dtype: int64
#
#
# Android          415074
# iOS              349206
# Windows          176464
# OS X              13174
# Unknown            4302
# Linux              1846
# android             636
# windows             431
# Windows Phone       173
# iphone              103
# ipad                 31
# mac                   9
# others                5
# BlackBerry            3
# Name: os, dtype: int64
#
#
# Phone       729615
# Computer    194017
# Tablet       37825
# Name: deviceType, dtype: int64
#
#
# 5ad6008850     574610
# a3036f8e67      77543
# ca10720d22      73514
# adcfa8aac4      38852
# 7260f81d98      34541
# b690e780f0      23140
# 558fb820ae      17852
# fadcc2c833      15593
# 9f8830f7bf      11264
# 7747c99aa4      10409
# 7e3fee842e      10093
# 1e0ce0bc6c       7853
# de184afdf3       6711
# 4ce500f989d      6426
# 6986953953       6291
# c5fcab9794       5716
# 1669db331b       4116
# 721f3799d6       4115
# 223727100b       4106
# 0e3a1a8bd8       4006
# 58f8225958       3140
# ba76c28c2c       2920
# 17ff555b8c       1790
# 21910dc609       1786
# 6b52d2a6e8       1649
# bf0e29cd55       1580
# 26b5e4c061       1422
# 1073a27ffd       1415
# b92d94c79d       1349
# 4a101d0c29       1306
#                 ...
# 9dd3332fdc        919
# 755dffed4e        617
# a92833a3ef        484
# 4113dd3c7b        330
# 042f5cf04b        165
# 483683f751        156
# e99b6a548b        152
# 46c7f4c651        141
# 78d13f130c        123
# 4996d019b0        122
# b1892a47b3        119
# 5b1287fe69         97
# 0d4fb169f9         96
# a1af7f300f         80
# 492b25a971         63
# 445347f8e0         52
# 26579599ab         35
# 2c2f1d69de         32
# edf6bafad6         17
# 80cad8d6af         10
# c1393c1ab9          9
# cced0b5053          7
# c77d2964e5          5
# 57f5a2fd70          4
# 3046                2
# 3720                2
# 3640                1
# a25606c9b2          1
# 0b9b2e3c02          1
# 46cec11619f         1
# Name: publisherId, Length: 62, dtype: int64
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                          162
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                   115
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                        60
# [{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                       59
# [{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":182,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                  20
# [{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                        18
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                        16
# [{""""""""""""""""id"""""""""""""""":301,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":0.75}]                                                                                                                                                                                                                                                                                                   14
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":317,""""""""""""""""weight"""""""""""""""":0.4148325},{""""""""""""""""id"""""""""""""""":284,""""""""""""""""weight"""""""""""""""":0.1754304},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.4097371}]                                                                                                          12
# [{""""""""""""""""id"""""""""""""""":408,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                         9
# [{""""""""""""""""id"""""""""""""""":231,""""""""""""""""weight"""""""""""""""":0.38738245},{""""""""""""""""id"""""""""""""""":926,""""""""""""""""weight"""""""""""""""":0.61261755}]                                                                                                                                                                                                                                                                                       9
# [{""""""""""""""""id"""""""""""""""":1379,""""""""""""""""weight"""""""""""""""":0.469151},{""""""""""""""""id"""""""""""""""":926,""""""""""""""""weight"""""""""""""""":0.530849}]                                                                                                                                                                                                                                                                                          8
# [{""""""""""""""""id"""""""""""""""":870,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                               6
# [{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                                                                                                                                                                                                         6
# [{""""""""""""""""id"""""""""""""""":622,""""""""""""""""weight"""""""""""""""":0.32967845},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":182,""""""""""""""""weight"""""""""""""""":0.23015402},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.44016755}]                                                                                                        5
# [{""""""""""""""""id"""""""""""""""":211,""""""""""""""""weight"""""""""""""""":0.2741867},{""""""""""""""""id"""""""""""""""":1049,""""""""""""""""weight"""""""""""""""":0.22269844},{""""""""""""""""id"""""""""""""""":1410,""""""""""""""""weight"""""""""""""""":0.3137925},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":409,""""""""""""""""weight"""""""""""""""":0.18932238}]            4
# [{""""""""""""""""id"""""""""""""""":203,""""""""""""""""weight"""""""""""""""":0.43641862},{""""""""""""""""id"""""""""""""""":1260,""""""""""""""""weight"""""""""""""""":0.5635814}]                                                                                                                                                                                                                                                                                       3
# [{""""""""""""""""id"""""""""""""""":244,""""""""""""""""weight"""""""""""""""":0.23089036},{""""""""""""""""id"""""""""""""""":245,""""""""""""""""weight"""""""""""""""":0.7691096},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                   3
# [{""""""""""""""""id"""""""""""""""":396,""""""""""""""""weight"""""""""""""""":0.33365816},{""""""""""""""""id"""""""""""""""":16,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":259,""""""""""""""""weight"""""""""""""""":0.27461603},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.18912822},{""""""""""""""""id"""""""""""""""":409,""""""""""""""""weight"""""""""""""""":0.20259759}]              3
# [{""""""""""""""""id"""""""""""""""":525,""""""""""""""""weight"""""""""""""""":0.18400854},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.3274604},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.48853105}]                                                                                                         3
# [{""""""""""""""""id"""""""""""""""":1033,""""""""""""""""weight"""""""""""""""":0.28872415},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1261,""""""""""""""""weight"""""""""""""""":0.34691334},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.3643625}]                                                                                                      3
# [{""""""""""""""""id"""""""""""""""":146,""""""""""""""""weight"""""""""""""""":0.76357377},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.23642623}]                                                                                                                                                                                                                                                                                       3
# [{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.41626152},{""""""""""""""""id"""""""""""""""":1174,""""""""""""""""weight"""""""""""""""":0.5837385}]                                                                                                                                                                                                                                                                                       3
# [{""""""""""""""""id"""""""""""""""":420,""""""""""""""""weight"""""""""""""""":0.20161456},{""""""""""""""""id"""""""""""""""":1364,""""""""""""""""weight"""""""""""""""":0.18937801},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.1960302},{""""""""""""""""id"""""""""""""""":949,""""""""""""""""weight"""""""""""""""":0.41297722}]            3
# [{""""""""""""""""id"""""""""""""""":907,""""""""""""""""weight"""""""""""""""":0.2621415},{""""""""""""""""id"""""""""""""""":276,""""""""""""""""weight"""""""""""""""":0.29583344},{""""""""""""""""id"""""""""""""""":122,""""""""""""""""weight"""""""""""""""":0.4420251}]                                                                                                                                                                                              2
# [{""""""""""""""""id"""""""""""""""":122,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":236,""""""""""""""""weight"""""""""""""""":0.71736246},{""""""""""""""""id"""""""""""""""":1526,""""""""""""""""weight"""""""""""""""":0.28263754}]                                                                                                                                                                                                  2
# [{""""""""""""""""id"""""""""""""""":1237,""""""""""""""""weight"""""""""""""""":0.7143397},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":429,""""""""""""""""weight"""""""""""""""":0.2856603}]                                                                                                                                                                                                    2
# [{""""""""""""""""id"""""""""""""""":78,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":276,""""""""""""""""weight"""""""""""""""":0.30094287},{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.27524516},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":0.42381197}]                                                                                                         2
# [{""""""""""""""""id"""""""""""""""":276,""""""""""""""""weight"""""""""""""""":0.18106057},{""""""""""""""""id"""""""""""""""":179,""""""""""""""""weight"""""""""""""""":0.101498276},{""""""""""""""""id"""""""""""""""":5058,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":1011,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":208,""""""""""""""""weight"""""""""""""""":0.21744116}]                 2
# [{""""""""""""""""id"""""""""""""""":1239,""""""""""""""""weight"""""""""""""""":0.22361933},{""""""""""""""""id"""""""""""""""":236,""""""""""""""""weight"""""""""""""""":0.18016341},{""""""""""""""""id"""""""""""""""":401,""""""""""""""""weight"""""""""""""""":0.19494292},{""""""""""""""""id"""""""""""""""":788,""""""""""""""""weight"""""""""""""""":0.2038601},{""""""""""""""""id"""""""""""""""":648,""""""""""""""""weight"""""""""""""""":0.19741422}]      2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":802,""""""""""""""""weight"""""""""""""""":0.36032134}]                                                                                                                                                                                                                                                                                              1
# [{""""""""""""""""id"""""""""""""""":78,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1374,""""""""""""""""weight"""""""""""""""":0.6442614},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":0.35573858}]                                                                                                                                                                                                    1
# [{""""""""""""""""id"""""""""""""""":420,""""""""""""""""weight"""""""""""""""":0.20801851},{""""""""""""""""id"""""""""""""""":236,""""""""""""""""weight"""""""""""""""":0.3907464},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":93,""""""""""""""""weight"""""""""""""""":0.4012351}]                                                                                                          1
# [{""""""""""""""""id"""""""""""""""":33,""""""""""""""""weight"""""""""""""""":0.22843532},{""""""""""""""""id"""""""""""""""":184,""""""""""""""""weight"""""""""""""""":0.18153434},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                    1
# [{""""""""""""""""id"""""""""""""""":78,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":276,""""""""""""""""weight"""""""""""""""":0.3733947},{""""""""""""""""id"""""""""""""""":960,""""""""""""""""weight"""""""""""""""":0.22770828},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":0.39889702}]                                                                                                          1
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1109,""""""""""""""""weight"""""""""""""""":0.31410673},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.6858933}]                                                                                                                                                                                                   1
# [{""""""""""""""""id"""""""""""""""":908,""""""""""""""""weight"""""""""""""""":0.25231904},{""""""""""""""""id"""""""""""""""":237,""""""""""""""""weight"""""""""""""""":0.26202342},{""""""""""""""""id"""""""""""""""":429,""""""""""""""""weight"""""""""""""""":0.48565757}]                                                                                                                                                                                            1
# [{""""""""""""""""id"""""""""""""""":122,""""""""""""""""weight"""""""""""""""":0.61981636},{""""""""""""""""id"""""""""""""""":1551,""""""""""""""""weight"""""""""""""""":0.38018364},{""""""""""""""""id"""""""""""""""":1174,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                           1
# [{""""""""""""""""id"""""""""""""""":301,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":250,""""""""""""""""weight"""""""""""""""":0.28598794},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.7140121}]                                                                                                               1
# [{""""""""""""""""id"""""""""""""""":1348,""""""""""""""""weight"""""""""""""""":0.32681963},{""""""""""""""""id"""""""""""""""":211,""""""""""""""""weight"""""""""""""""":0.19786783},{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.22411178},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.25120077}]                                                                                                1
# [{""""""""""""""""id"""""""""""""""":211,""""""""""""""""weight"""""""""""""""":0.32398129},{""""""""""""""""id"""""""""""""""":1310,""""""""""""""""weight"""""""""""""""":0.2573086},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1095,""""""""""""""""weight"""""""""""""""":0.4187101}]                                                                                                       1
# [{""""""""""""""""id"""""""""""""""":1239,""""""""""""""""weight"""""""""""""""":0.22201179},{""""""""""""""""id"""""""""""""""":611,""""""""""""""""weight"""""""""""""""":0.22053017},{""""""""""""""""id"""""""""""""""":633,""""""""""""""""weight"""""""""""""""":0.22643685},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.3310212}]            1
# [{""""""""""""""""id"""""""""""""""":78,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":346,""""""""""""""""weight"""""""""""""""":0.2720889},{""""""""""""""""id"""""""""""""""":1320,""""""""""""""""weight"""""""""""""""":0.26106387},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":0.20311314},{""""""""""""""""id"""""""""""""""":717,""""""""""""""""weight"""""""""""""""":0.26373413}]              1
# [{""""""""""""""""id"""""""""""""""":33,""""""""""""""""weight"""""""""""""""":0.22140098},{""""""""""""""""id"""""""""""""""":396,""""""""""""""""weight"""""""""""""""":0.26201874},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.2221902}]                                                                                                          1
# [{""""""""""""""""id"""""""""""""""":443,""""""""""""""""weight"""""""""""""""":0.16931123},{""""""""""""""""id"""""""""""""""":1136,""""""""""""""""weight"""""""""""""""":0.21723069},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":507,""""""""""""""""weight"""""""""""""""":0.20529835},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.40815973}]           1
# [{""""""""""""""""id"""""""""""""""":1459,""""""""""""""""weight"""""""""""""""":0.36403352},{""""""""""""""""id"""""""""""""""":1457,""""""""""""""""weight"""""""""""""""":0.17245801},{""""""""""""""""id"""""""""""""""":107,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1163,""""""""""""""""weight"""""""""""""""":0.75}]                                                                                                           1
# [{""""""""""""""""id"""""""""""""""":33,""""""""""""""""weight"""""""""""""""":0.5046573},{""""""""""""""""id"""""""""""""""":211,""""""""""""""""weight"""""""""""""""":0.19894102},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.29640165}]                                                                                                                                                                                              1
# [{""""""""""""""""id"""""""""""""""":1135,""""""""""""""""weight"""""""""""""""":0.25234842},{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.32785392},{""""""""""""""""id"""""""""""""""":1174,""""""""""""""""weight"""""""""""""""":0.22381698},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.1959807}]                                                                                                1
# [{""""""""""""""""id"""""""""""""""":398,""""""""""""""""weight"""""""""""""""":0.45115975},{""""""""""""""""id"""""""""""""""":964,""""""""""""""""weight"""""""""""""""":0.5488403},{""""""""""""""""id"""""""""""""""":1482,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                   1
# [{""""""""""""""""id"""""""""""""""":78,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":1383,""""""""""""""""weight"""""""""""""""":0.26237673},{""""""""""""""""id"""""""""""""""":307,""""""""""""""""weight"""""""""""""""":0.7376233}]                                                                                                                                                                                                    1
# [{""""""""""""""""id"""""""""""""""":246,""""""""""""""""weight"""""""""""""""":0.6789005},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.32109952}]                                                                                                                                                                                                                                                                                        1
# [{""""""""""""""""id"""""""""""""""":1033,""""""""""""""""weight"""""""""""""""":0.2181777},{""""""""""""""""id"""""""""""""""":1021,""""""""""""""""weight"""""""""""""""":0.18362562},{""""""""""""""""id"""""""""""""""":1261,""""""""""""""""weight"""""""""""""""":0.18325041},{""""""""""""""""id"""""""""""""""":1260,""""""""""""""""weight"""""""""""""""":0.41494626}]                                                                                              1
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.51469696}]                                                                                                                                                                                                                                                                                              1
# [{""""""""""""""""id"""""""""""""""":276,""""""""""""""""weight"""""""""""""""":0.16431451},{""""""""""""""""id"""""""""""""""":448,""""""""""""""""weight"""""""""""""""":0.20687474},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":449,""""""""""""""""weight"""""""""""""""":0.2068778},{""""""""""""""""id"""""""""""""""":608,""""""""""""""""weight"""""""""""""""":0.42193294}]              1
# [{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":926,""""""""""""""""weight"""""""""""""""":0.28816307},{""""""""""""""""id"""""""""""""""":372,""""""""""""""""weight"""""""""""""""":0.357126}]                                                                                                                                                                                                     1
# [{""""""""""""""""id"""""""""""""""":276,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":5388,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":1011,""""""""""""""""weight"""""""""""""""":1.0}]                                                                                                                                                                                                               1
# [{""""""""""""""""id"""""""""""""""":78,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":47,""""""""""""""""weight"""""""""""""""":0.42452803},{""""""""""""""""id"""""""""""""""":858,""""""""""""""""weight"""""""""""""""":0.57547194}]                                                                                                                                                                                                     1
# [{""""""""""""""""id"""""""""""""""":144,""""""""""""""""weight"""""""""""""""":0.2658264},{""""""""""""""""id"""""""""""""""":1211,""""""""""""""""weight"""""""""""""""":0.7341736}]                                                                                                                                                                                                                                                                                        1
# [{""""""""""""""""id"""""""""""""""":264,""""""""""""""""weight"""""""""""""""":0.46725792},{""""""""""""""""id"""""""""""""""":191,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":280,""""""""""""""""weight"""""""""""""""":0.19448636}]                                                                                                                                                                                                   1
# [{""""""""""""""""id"""""""""""""""":907,""""""""""""""""weight"""""""""""""""":0.5861292},{""""""""""""""""id"""""""""""""""":694,""""""""""""""""weight"""""""""""""""":0.75},{""""""""""""""""id"""""""""""""""":122,""""""""""""""""weight"""""""""""""""":1.0},{""""""""""""""""id"""""""""""""""":504,""""""""""""""""weight"""""""""""""""":0.5},{""""""""""""""""id"""""""""""""""":1526,""""""""""""""""weight"""""""""""""""":0.20291117}]                          1
# Name: dclkVerticals, Length: 651, dtype: int64
#
#
# 4612    199557
# 4636    189655
# 4610    129622
# 4597     67173
# 4596     59460
# 4608     48434
# 4506     26825
# 4626     26588
# 4635     25052
# 4619     23958
# 4603     19668
# 4574     19234
# 4607     15388
# 4632     14499
# 4627     12685
# 4571     12575
# 4575     11382
# 4558      9730
# 4625      8814
# 4518      7804
# 4591      6011
# 4602      4269
# 4630      3870
# 4620      3670
# 4631      3307
# 4600      1450
# 4609      1329
# 4613      1131
# 4601      1116
# 4540      1063
# 4634      1048
# 4629       857
# 4633       742
# 4611       600
# 4628       566
# 4599       461
# 4588       431
# 4589       374
# 4604       309
# 4586       175
# 4587       166
# 4578       158
# 4623       152
# 4577        68
# 4621        17
# 4590         4
# 4614         4
# 4521         4
# 4576         2
# Name: campaignId, dtype: int64
#
#
# 94     214707
# 266    199557
# 173    179985
# 215    151809
# 271     56687
# 260     34629
# 127     19977
# 96      19236
# 272     15388
# 273     14499
# 237     12575
# 268     11382
# 265      9730
# 246      7296
# 250      6011
# 240      3687
# 269      1790
# 251      1135
# 267      1063
# 41        158
# 64        152
# 16          4
# Name: advertiserId, dtype: int64
#
#
# 0    960864
# 1       593
# Name: click, dtype: int64

# %%
adx = all_df.loc[:,('adx', 'click')]
adx['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
adx.groupby(['adx'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False)
# Out:
#                                             adx     click   count
# 0  CuXcT8n6P0sIIAJUDjlunuV0ZnzP7p3Xf1jHLo2OlOE=  0.000821    1218
# 1  oN9K9JVNmtH69Q1KBbhHUtZ34mw/vdefue3wgNg/kWU=  0.000617  960239

# %%
spt = all_df.loc[:,('spaceType', 'click')]
spt['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
spt.groupby(['spaceType'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False)
# Out:
#   spaceType     click   count
# 1      site  0.000619  958317
# 0       app  0.000000    3140

# %%
spd = all_df.loc[:,('spaceId', 'click')]
spd['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
spd.groupby(['spaceId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#               spaceId     click  count
# 105  7f068f54a11e4d56  0.120120    666
# 54   44b9221f3c5742d3  0.056604    742
# 229  fbadbe0b84574e6c  0.047619     21
# 119  8e2e462a46df4439  0.039122   1048
# 129  a0faeba51aec4944  0.037007   1216
# 110  835efb3468c24b8d  0.036364    330
# 205  e53805fd0b0f45d7  0.026087    230
# 191  d9055bc9592444e0  0.013475   2449
# 1    00b07139e7c2469f  0.012500     80
# 85   655005bab3a9414d  0.011494     87

# %%
sct = all_df.loc[:,('spaceCat', 'click')]
sct['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
sct.groupby(['spaceCat'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#     spaceCat     click   count
# 11  IAB19_18  0.032698     367
# 13      IAB2  0.008547     117
# 4      IAB13  0.006098     164
# 0       IAB1  0.005423   17701
# 5    IAB14_1  0.001646  104502
# 19      IAB8  0.001630   11046
# 15     IAB22  0.001445     692
# 20      IAB9  0.001295     772
# 9      IAB18  0.001221    5732
# 8      IAB17  0.000616   17858

# %%
adt = all_df.loc[:,('adType', 'click')]
adt['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
adt.groupby(['adType'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#           adType     click   count
# 5            [4]  0.046369    1790
# 3      [1,2,5,7]  0.001299     770
# 4          [3,9]  0.000531  958295
# 0  [1,2,5,6,7,8]  0.000000      49
# 1    [1,2,5,6,7]  0.000000     448
# 2    [1,2,5,7,8]  0.000000     105

# %%
ip = all_df.loc[:,('ip', 'click')]
ip['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
ip.groupby(['ip'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#                                                   ip  click  count
# 329527  RQEikp3eipwmVfhBjwR/y8m01J0p+fF9emMe5RTfpHk=    1.0      1
# 185973  EbO84/dGxPzxlsuF3+hPNgD8fnedwD8Ec+xBgV9YpAg=    1.0      1
# 407741  YTKRw6rz7VigqF+GQwUOBljyNE7ceNJYS6PSp9a0KRg=    1.0      1
# 31205   0mCHfOi7qOiprjoJAUJ+KC+7tXKOp2FwHlAhhqCDLZE=    1.0      1
# 442421  bXhKxDjPEabRXQUAUsONNJ1jXPXfxWkYDnukForHGxU=    1.0      1
# 10156   +uAuX0tIXxhHu1d/7LFR8+oQU3PZ/xwJc64SY2lgJJ4=    1.0      1
# 575581  nVD+fv9iOmVE6sXQtaNdVa9OfU/gEKobWU8cTsof1VE=    1.0      1
# 519762  iVgZutnakWInIdVj2fpLSo0F6Us335nB6Q5QIT4NtUU=    1.0      1
# 249711  KJ09JCOTaHI2xraFt7dUxtubGi6i6xXwNskLU1RNJ5M=    1.0      1
# 525222  j+cXPiok35Qt2mjsY12CJ84UOWQu1emkch2nkPClvz0=    1.0      1

# %%
os = all_df.loc[:,('os', 'click')]
os['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
os.groupby(['os'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#               os     click   count
# 6  Windows Phone  0.005780     173
# 7        android  0.001572     636
# 2          Linux  0.001083    1846
# 0        Android  0.000889  415074
# 4        Unknown  0.000697    4302
# 3           OS X  0.000683   13174
# 5        Windows  0.000618  176464
# 8            iOS  0.000284  349206
# 1     BlackBerry  0.000000       3
# 9           ipad  0.000000      31

# %%
dvt = all_df.loc[:,('deviceType', 'click')]
dvt['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
dvt.groupby(['deviceType'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#   deviceType     click   count
# 2     Tablet  0.000740   37825
# 0   Computer  0.000634  194017
# 1      Phone  0.000606  729615

# %%
pid = all_df.loc[:,('publisherId', 'click')]
pid['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
pid.groupby(['publisherId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#    publisherId     click  count
# 49  b92d94c79d  0.060044   1349
# 7   17ff555b8c  0.046369   1790
# 17  4113dd3c7b  0.036364    330
# 6   1669db331b  0.011176   4116
# 10  223727100b  0.008281   4106
# 21  483683f751  0.006410    156
# 50  ba76c28c2c  0.002397   2920
# 3   0e3a1a8bd8  0.001747   4006
# 33  721f3799d6  0.001701   4115
# 35  755dffed4e  0.001621    617

# %%
dcv = all_df.loc[:,('dclkVerticals', 'click')]
dcv['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
dcv.groupby(['dclkVerticals'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#                                          dclkVerticals  click  count
# 521  [{""""""""""""""""id"""""""""""""""":58,""""""...      1      1
# 0                                                   []      0    162
# 438  [{""""""""""""""""id"""""""""""""""":422,"""""...      0      1
# 431  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 432  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 433  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 434  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 435  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 436  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1
# 437  [{""""""""""""""""id"""""""""""""""":420,"""""...      0      1

# %%
cid = all_df.loc[:,('campaignId', 'click')]
cid['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
cid.groupby(['campaignId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#     campaignId     click  count
# 35        4621  0.176471     17
# 24        4604  0.067961    309
# 45        4633  0.056604    742
# 29        4611  0.053333    600
# 27        4609  0.045899   1329
# 46        4634  0.039122   1048
# 9         4577  0.014706     68
# 16        4591  0.003161   6011
# 3         4540  0.002822   1063
# 47        4635  0.001876  25052

# %%
aid = all_df.loc[:,('advertiserId', 'click')]
aid['count'] = 1
aggregator = {'click': 'mean', 'count': 'sum'}
aid.groupby(['advertiserId'], as_index=False).agg(aggregator).sort_values(by='click', ascending=False).head(10)
# Out:
#     advertiserId     click   count
# 18           269  0.046369    1790
# 11           250  0.003161    6011
# 16           267  0.002822    1063
# 8            237  0.001670   12575
# 5            127  0.001602   19977
# 9            240  0.001356    3687
# 21           273  0.000897   14499
# 6            173  0.000817  179985
# 20           272  0.000780   15388
# 17           268  0.000703   11382

# %%
# Correlations to "click" are all very low.
# We should kick out some trash categories which has almost nothing to do with "click".
# Note the special case with "dclkVerticals", which has lots NaN entry. There are 2 ways to cope with it. Remove it or make the values 0 for NaN, otherwise 1.
# Categories that are probably no use( abs() < 0.01 ): deviceType, spaceType, dclkVerticals, adx, ip, os(?)

df_drop = all_df.drop(['deviceType', 'spaceType', 'dclkVerticals', 'adx', 'ip'], axis = 1).loc[:,:]
df_drop.head(10)
# Out:
#             spaceId spaceCat adType       os publisherId  campaignId  \
# 0  4d5aa536cd864b8d    IAB12  [3,9]  Android  5ad6008850        4612
# 1  df29ee4288fb474d  IAB14_1  [3,9]  Android  ca10720d22        4619
# 2  fabac3bca4a34996    IAB12  [3,9]  Android  adcfa8aac4        4597
# 3  946bc0ae7ddf40a3    IAB12  [3,9]  Windows  de184afdf3        4608
# 4  4d5aa536cd864b8d    IAB12  [3,9]  Android  5ad6008850        4612
# 5  4d5aa536cd864b8d    IAB12  [3,9]      iOS  5ad6008850        4612
# 6  d0850c0f52434b05    IAB12  [3,9]  Windows  5ad6008850        4610
# 7  fa604d518ae1467e  IAB9_30  [3,9]  Android  a3036f8e67        4612
# 8  fabac3bca4a34996    IAB12  [3,9]  Windows  adcfa8aac4        4596
# 9  4d5aa536cd864b8d    IAB12  [3,9]      iOS  5ad6008850        4612
#
#    advertiserId  click
# 0           266      0
# 1           215      0
# 2           215      0
# 3           173      0
# 4           266      0
# 5           266      0
# 6           173      0
# 7           266      0
# 8           215      0
# 9           266      0

# %%
df_final = pd.get_dummies(df_drop, columns=list(df_drop)[:-1])

# %%
 print(df_final['click'].value_counts())
# Out:
# 0    960864
# 1       593
# Name: click, dtype: int64

# %%
pos = df_final[df_final['click'] == 1].sample(frac=1)
pos = np.split(pos, [df_final['click'].value_counts()[1] // 10 * 2], axis = 0)
train = pos[1]
# train = train.append([pos[1]] * 99, ignore_index=True)
test = pos[0]
neg = df_final[df_final['click'] == 0].sample(frac=1)
neg = np.split(neg, [df_final['click'].value_counts()[0] // 10 * 2], axis = 0)
train = train.append(neg[1], ignore_index=True).sample(frac=1)
test = test.append(neg[0], ignore_index=True).sample(frac=1)
X_train = train.drop(['click'], axis = 1)
Y_train = train['click']
X_test = test.drop(['click'], axis = 1)
Y_test = test['click']
sc = StandardScaler()
sc.fit(X_train)
X_trstd = sc.transform(X_train)
X_tsstd = sc.transform(X_test)

# %%
# PCA
cov_mat = np.cov(X_trstd.T)
eigen_vals, eigen_vecs = np.linalg.eig(cov_mat
#    1.02077320e-16 -1.99670725e-16j  -2.70839432e-16 +0.00000000e+00j
#   -2.35814385e-16 +3.12963227e-17j  -2.35814385e-16 -3.12963227e-17j
#   -7.15206103e-17 +1.81724936e-16j  -7.15206103e-17 -1.81724936e-16j
#   -1.32972942e-16 +1.39619770e-16j  -1.32972942e-16 -1.39619770e-16j
#    1.21259296e-16 +1.23601137e-16j   1.21259296e-16 -1.23601137e-16j
#    1.52116565e-16 +6.94637096e-17j   1.52116565e-16 -6.94637096e-17j
#   -1.63389968e-16 +0.00000000e+00j   1.84851692e-17 +1.14627374e-16j
#    1.84851692e-17 -1.14627374e-16j   1.12405362e-16 +0.00000000e+00j
#   -1.63378225e-17 +6.91914807e-17j  -1.63378225e-17 -6.91914807e-17j
#    7.35719413e-17 +0.00000000e+00j  -8.28713257e-17 +0.00000000e+00j
#    3.16911143e-17 +0.00000000e+00j  -2.63954623e-17 +0.00000000e+00j
#    2.03751448e-18 +0.00000000e+00j   1.00000260e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j
#    0.00000000e+00 +0.00000000e+00j   0.00000000e+00 +0.00000000e+00j]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.2)
X_trpca = pca.fit_transform(X_trstd)
X_tspca = pca.transform(X_tsstd)
pca.explained_variance_ratio_
# Out:
# array([ 0.01324138,  0.01108423,  0.01093896,  0.00984291,  0.00933041,
#         0.00714724,  0.00697599,  0.0068544 ,  0.00684829,  0.00657526,
#         0.00652157,  0.00645451,  0.0064094 ,  0.00636232,  0.00632885,
#         0.00631874,  0.0062667 ,  0.00612364,  0.00611313,  0.00599316,
#         0.00584834,  0.00574284,  0.00572034,  0.00542575,  0.00535188,
#         0.00521274,  0.00489036,  0.00487523,  0.00482899,  0.00481178])

# %%
clf = RandomForestClassifier(n_estimators=100, n_jobs=-2, class_weight={0:1, 1:10})
clf.fit(X_trpca, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 10},
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=-2, oob_score=False,
#             random_state=None, verbose=0, warm_start=False)

# %%
tn, fp, fn, tp = confusion_matrix(clf.predict(X_tspca), Y_test).ravel()
(tn, fp, fn, tp)
# Out:
# (192029, 94, 143, 24)

# %%
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(clf.predict(X_tspca), Y_test))
# Out:
# 0.998767486609
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00    192123
#           1       0.20      0.14      0.17       167
#
# avg / total       1.00      1.00      1.00    192290

# %%
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]
for f in range(X_tspca.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 60, df_final.columns[1:][f], importances[indices[f]]))
# Out:
#  1) spaceId_00a10127a9834bf3                                     0.088567
#  2) spaceId_00b07139e7c2469f                                     0.065706
#  3) spaceId_023fb23d52714e9e                                     0.060371
#  4) spaceId_03c1df85b408454d                                     0.058324
#  5) spaceId_04fcb658d5d546eb                                     0.057988
#  6) spaceId_05add4abe3ea46c8                                     0.052572
#  7) spaceId_06698a05389c416e                                     0.044738
#  8) spaceId_07266f676d684613                                     0.036268
#  9) spaceId_08716dcda11a4dca                                     0.035308
# 10) spaceId_0931c4b63d6c421e                                     0.034577
# 11) spaceId_0b60a577ef1b4907                                     0.033093
# 12) spaceId_0bde96c547ed4e07                                     0.032099
# 13) spaceId_0f8234666bfa42a4                                     0.030072
# 14) spaceId_0faa8f92844e49c0                                     0.030063
# 15) spaceId_10d7573588ac4fea                                     0.029543
# 16) spaceId_11550b3c773d493b                                     0.028105
# 17) spaceId_1268ef47194b4404                                     0.027584
# 18) spaceId_12b83249d39b4e94                                     0.024671
# 19) spaceId_12e4122a3a974681                                     0.023568
# 20) spaceId_1518c1359fc14af5                                     0.023164
# 21) spaceId_1545b4697b874fdc                                     0.020105
# 22) spaceId_1594dbbf247b46a1                                     0.019859
# 23) spaceId_16935bb933d54c9e                                     0.019677
# 24) spaceId_18c83c15a9424c80                                     0.019399
# 25) spaceId_1a2687687697428b                                     0.019337
# 26) spaceId_1b35be0e43ce4d40                                     0.019306
# 27) spaceId_1bbcbcd4f42e4a35                                     0.019044
# 28) spaceId_1bf0eeda8dde463f                                     0.015908
# 29) spaceId_1fbb301d837049ef                                     0.015903
# 30) spaceId_22332037104249df                                     0.015079

# %%
# LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis(n_components=100)
X_trlda = lda.fit_transform(X_trstd, Y_train)
X_tslda = lda.transform(X_tsstd)
lda.explained_variance_ratio_
# Out:
# c:\users\superdanby\appdata\local\conda\conda\envs\ai\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# array([ 1.])

# %%
clf = RandomForestClassifier(n_estimators=50, n_jobs=-2, class_weight={0:1, 1:10})
clf.fit(X_trlda, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight={0: 1, 1: 10},
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=50, n_jobs=-2, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
tn, fp, fn, tp = confusion_matrix(clf.predict(X_tslda), Y_test).ravel()
(tn, fp, fn, tp)
# Out:
# (192036, 94, 136, 24)

# %%
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(clf.predict(X_tslda), Y_test))
# Out:
# 0.998803889958
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00    192130
#           1       0.20      0.15      0.17       160
#
# avg / total       1.00      1.00      1.00    192290

# %%
pos = df_final[df_final['click'] == 1].sample(frac=1)
pos = np.split(pos, [df_final['click'].value_counts()[1] // 100 * 2], axis = 0)
train = pos[1]
# train = train.append([pos[1]] * 99, ignore_index=True)
test = pos[0]
neg = df_final[df_final['click'] == 0].sample(frac=1)
neg = np.split(neg, [df_final['click'].value_counts()[0] // 10 * 2], axis = 0)
train = train.append(neg[1], ignore_index=True).sample(frac=1)
test = test.append(neg[0], ignore_index=True).sample(frac=1)
X_train = train.drop(['click'], axis = 1)
Y_train = train['click']
X_test = test.drop(['click'], axis = 1)
Y_test = test['click']
sc = StandardScaler()
sc.fit(X_train)
X_trstd = sc.transform(X_train)
X_tsstd = sc.transform(X_test)
pca = PCA(n_components = 50)
X_trpca = pca.fit_transform(X_trstd)
X_tspca = pca.transform(X_tsstd)
pca.explained_variance_ratio_
# Out:
# array([ 0.01312949,  0.01098539,  0.01086145,  0.0097509 ,  0.00924785,
#         0.00707139,  0.00690101,  0.00679602,  0.00677908,  0.00647195,
#         0.00643965,  0.00636631,  0.00632494,  0.00625896,  0.00623849,
#         0.00621178,  0.0061413 ,  0.00603175,  0.00598909,  0.00587137,
#         0.00572944,  0.00563229,  0.00557056,  0.00530102,  0.00525167,
#         0.00505632,  0.00476382,  0.00472014,  0.00469356,  0.00458872,
#         0.00452476,  0.0044847 ,  0.00445419,  0.00435976,  0.00433193,
#         0.00429449,  0.00429326,  0.00427413,  0.00425442,  0.00423635,
#         0.00423081,  0.00421888,  0.00421507,  0.00420293,  0.00420037,
#         0.00419025,  0.00418453,  0.00417468,  0.0041666 ,  0.00415163])

# %%
param_grid = [
#     {'C': [0.01, 0.1, 1, 10, 100], 'kernel': ['linear']},
   {'C': [0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, (1 / 6)], 'kernel': ['rbf']},
#    {'C': [0.01, 0.1, 1, 10, 100], 'kernel': ['poly']},
#    {'C': [0.01, 0.1, 1, 10, 100], 'kernel': ['sigmoid']},
 ]
clf = GridSearchCV(SVC(), param_grid, n_jobs = -2, scoring = 'f1')
clf.fit(X_trpca, Y_train)

# %%
tn, fp, fn, tp = confusion_matrix(clf.predict(X_tspca), Y_test).ravel()
print((tp + tn) / (tp + tn + fp + fn))
print(classification_report(clf.predict(X_tspca), Y_test))
